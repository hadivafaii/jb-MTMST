# %% [markdown]
# # (01) Neural $\beta$ results (GABAN)
#
# **Motivation**: Fits on GABAN <br>

# %%
# HIDE CODE


import os, sys
from IPython.display import display

# tmp & extras dir
git_dir = os.path.join(os.environ['HOME'], 'Dropbox/git')
extras_dir = os.path.join(git_dir, 'jb-MTMST/_extras')
fig_base_dir = os.path.join(git_dir, 'jb-MTMST/figs')
tmp_dir = os.path.join(git_dir, 'jb-MTMST/tmp')

# GitHub
sys.path.insert(0, os.path.join(git_dir, '_MTMST'))
from vae.train_vae import TrainerVAE, ConfigTrainVAE
from vae.vae2d import VAE, ConfigVAE
from figures.fighelper import *
from analysis.glm import *


# warnings, tqdm, & style
warnings.filterwarnings('ignore', category=DeprecationWarning)
from rich.jupyter import print
# %matplotlib inline
set_style()

# %%
fits = [
    'transl2_k-32_z-20x[3,6,12]_enc(1x3)-dec(1x2)-pre(1x3)-post(1x3)/ep160-b600-lr(0.002)_beta(0.5:0x0.5)_lamb(0.0001)_gr(250.0)_(2023_05_15,07:27)',
]
save_script_neural(fits, 'cuda')
# Out:
# [PROGRESS] 'run_neuron_gaban.txt' saved at
# /home/hadi/Dropbox/git/_MTMST/scripts

# %% [markdown]
# ## Fixate 2

# %% [markdown]
# ### $\beta = 5$

# %%
fit_name = 'fixate2_nf-420_beta-5.0_(2023_05_15,08:46)'
df, df_all, ro_all, args, tr = summarize_neural_fits(fit_name)

_ = show_neural_results(df)
len(df)
# Out:
# 141

# %%
inds = df['perf'].argsort()[::-1]
df.iloc[inds]
# Out:
#     category   nf  beta   root    expt  cell      perf  max_perf  log_alpha  \
# 118  fixate2  420   5.0  YUWEI  ytu028     8  1.060234  0.328052        1.0
# 51   fixate2  420   5.0  YUWEI  clu221     3  0.891967  0.900849      -10.0
# 42   fixate2  420   5.0  YUWEI  clu209     1  0.872689  0.923722      -10.0
# 49   fixate2  420   5.0  YUWEI  clu221     1  0.861053  0.924544      -10.0
# 50   fixate2  420   5.0  YUWEI  clu221     2  0.853288  0.921324      -10.0
# ..       ...  ...   ...    ...     ...   ...       ...       ...        ...
# 96   fixate2  420   5.0  YUWEI  clu294     2  0.105524       NaN        2.0
# 38   fixate2  420   5.0  YUWEI  clu180     0  0.101125       NaN      -10.0
# 97   fixate2  420   5.0  YUWEI  clu294     3  0.080969       NaN        2.0
# 13   fixate2  420   5.0  YUWEI  clu069     0  0.060781       NaN      -10.0
# 102  fixate2  420   5.0  YUWEI  clu294     9  0.046163       NaN        2.0
#
#      best_lag
# 118         8
# 51          3
# 42          4
# 49          4
# 50          4
# ..        ...
# 96          5
# 38         12
# 97         10
# 13          4
# 102        12
#
# [141 rows x 10 columns]

# %% [markdown]
# ## Fixate 1 (vanilla)

# %% [markdown]
# ### $\beta = 5$

# %%
fit_name = 'vanilla_fixate1_nf-420_beta-5.0_(2023_05_15,07:23)'
df, df_all, ro_all, args, tr = summarize_neural_fits(fit_name)

_ = show_neural_results(df)
len(df)
# Out:
# 141

# %%
inds = df['perf'].argsort()[::-1]
df.iloc[inds]
# Out:
#     category   nf  beta   root    expt  cell      perf  max_perf  log_alpha  \
# 51   fixate1  420   5.0  YUWEI  clu221     3  0.919576  0.900849      -10.0
# 42   fixate1  420   5.0  YUWEI  clu209     1  0.881883  0.923722      -10.0
# 43   fixate1  420   5.0  YUWEI  clu209     4  0.834825  0.933615      -10.0
# 28   fixate1  420   5.0  YUWEI  clu116     0  0.834029  0.835483       -8.0
# 49   fixate1  420   5.0  YUWEI  clu221     1  0.822745  0.924544       -6.0
# ..       ...  ...   ...    ...     ...   ...       ...       ...        ...
# 38   fixate1  420   5.0  YUWEI  clu180     0  0.118874       NaN       -6.0
# 96   fixate1  420   5.0  YUWEI  clu294     2  0.117167       NaN       -4.0
# 13   fixate1  420   5.0  YUWEI  clu069     0  0.069367       NaN       -6.0
# 97   fixate1  420   5.0  YUWEI  clu294     3  0.068601       NaN       -4.0
# 102  fixate1  420   5.0  YUWEI  clu294     9  0.062357       NaN       -4.0
#
#      best_lag
# 51          4
# 42          3
# 43          2
# 28          3
# 49          3
# ..        ...
# 38         10
# 96          9
# 13          4
# 97          4
# 102         3
#
# [141 rows x 10 columns]

# %% [markdown]
# ### $\beta = 1.5$

# %%
fit_name = 'vanilla_fixate1_nf-420_beta-1.5_(2023_05_14,14:16)'
df, df_all, ro_all, args, tr = summarize_neural_fits(fit_name)

_ = show_neural_results(df)
len(df)
# Out:
# 141

# %%
inds = df['perf'].argsort()[::-1]
df.iloc[inds]
# Out:
#     category   nf  beta   root    expt  cell      perf  max_perf  log_alpha  \
# 51   fixate1  420   1.5  YUWEI  clu221     3  0.899095  0.900849       -6.0
# 42   fixate1  420   1.5  YUWEI  clu209     1  0.869517  0.923722       -4.0
# 49   fixate1  420   1.5  YUWEI  clu221     1  0.859832  0.924544       -8.0
# 50   fixate1  420   1.5  YUWEI  clu221     2  0.848201  0.921324       -6.0
# 28   fixate1  420   1.5  YUWEI  clu116     0  0.843442  0.835483      -10.0
# ..       ...  ...   ...    ...     ...   ...       ...       ...        ...
# 103  fixate1  420   1.5  YUWEI  clu294    10  0.117285       NaN       -4.0
# 96   fixate1  420   1.5  YUWEI  clu294     2  0.112612       NaN       -4.0
# 13   fixate1  420   1.5  YUWEI  clu069     0  0.067252       NaN       -2.0
# 97   fixate1  420   1.5  YUWEI  clu294     3  0.066390       NaN       -4.0
# 102  fixate1  420   1.5  YUWEI  clu294     9  0.053368       NaN       -4.0
#
#      best_lag
# 51          3
# 42          3
# 49          3
# 50          3
# 28          3
# ..        ...
# 103         8
# 96         10
# 13          5
# 97          9
# 102         4
#
# [141 rows x 10 columns]

# %% [markdown]
# ### $\beta = 0.9$

# %%
fit_name = 'vanilla_fixate1_nf-420_beta-0.9_(2023_05_13,20:45)'
df, df_all, ro_all, args, tr = summarize_neural_fits(fit_name)

_ = show_neural_results(df)
len(df)
# Out:
# 141

# %%
inds = df['perf'].argsort()[::-1]
df.iloc[inds]
# Out:
#     category   nf  beta   root    expt  cell      perf  max_perf  log_alpha  \
# 42   fixate1  420   0.9  YUWEI  clu209     1  0.899845  0.923722       -4.0
# 51   fixate1  420   0.9  YUWEI  clu221     3  0.884605  0.900849       -8.0
# 28   fixate1  420   0.9  YUWEI  clu116     0  0.882997  0.835483      -10.0
# 124  fixate1  420   0.9  YUWEI  ytu029     4  0.873919  0.935583       -6.0
# 49   fixate1  420   0.9  YUWEI  clu221     1  0.839540  0.924544      -10.0
# ..       ...  ...   ...    ...     ...   ...       ...       ...        ...
# 96   fixate1  420   0.9  YUWEI  clu294     2  0.110039       NaN       -4.0
# 13   fixate1  420   0.9  YUWEI  clu069     0  0.062551       NaN       -6.0
# 97   fixate1  420   0.9  YUWEI  clu294     3  0.059792       NaN       -4.0
# 102  fixate1  420   0.9  YUWEI  clu294     9  0.052290       NaN       -4.0
# 40   fixate1  420   0.9  YUWEI  clu183     0  0.017471  0.927126        8.0
#
#      best_lag
# 42          3
# 51          4
# 28          3
# 124         4
# 49          5
# ..        ...
# 96         12
# 13          4
# 97          8
# 102         0
# 40         12
#
# [141 rows x 10 columns]

# %% [markdown]
# ### $\beta = 0.3$

# %%
fit_name = 'vanilla_fixate1_nf-420_beta-0.3_(2023_05_13,07:46)'
df, df_all, ro_all, args, tr = summarize_neural_fits(fit_name)

_ = show_neural_results(df)
len(df)
# Out:
# 141

# %%
inds = df['perf'].argsort()[::-1]
df.iloc[inds]
# Out:
#     category   nf  beta   root    expt  cell      perf  max_perf  log_alpha  \
# 42   fixate1  420   0.3  YUWEI  clu209     1  0.922681  0.923722       -2.0
# 49   fixate1  420   0.3  YUWEI  clu221     1  0.902338  0.924544      -10.0
# 69   fixate1  420   0.3  YUWEI  clu267     4  0.878455  0.979806       -2.0
# 51   fixate1  420   0.3  YUWEI  clu221     3  0.877364  0.900849       -2.0
# 43   fixate1  420   0.3  YUWEI  clu209     4  0.864591  0.933615       -1.0
# ..       ...  ...   ...    ...     ...   ...       ...       ...        ...
# 97   fixate1  420   0.3  YUWEI  clu294     3  0.071649       NaN        0.0
# 13   fixate1  420   0.3  YUWEI  clu069     0  0.067696       NaN       -1.0
# 102  fixate1  420   0.3  YUWEI  clu294     9  0.057907       NaN       -1.0
# 31   fixate1  420   0.3  YUWEI  clu131     0  0.055797  0.843686       -1.0
# 34   fixate1  420   0.3  YUWEI  clu145     0  0.046644  0.593791        2.0
#
#      best_lag
# 42          4
# 49          4
# 69          3
# 51          4
# 43          3
# ..        ...
# 97          3
# 13          4
# 102         0
# 31          5
# 34          0
#
# [141 rows x 10 columns]

# %% [markdown]
# ### $\beta = 0.6$

# %%
fit_name = 'vanilla_fixate1_nf-420_beta-0.6_(2023_05_12,18:12)'
df, df_all, ro_all, args, tr = summarize_neural_fits(fit_name)

_ = show_neural_results(df)
len(df)
# Out:
# 141

# %%
inds = df['perf'].argsort()[::-1]
df.iloc[inds]
# Out:
#     category   nf  beta   root    expt  cell      perf  max_perf  log_alpha  \
# 42   fixate1  420   0.6  YUWEI  clu209     1  0.873347  0.923722       -6.0
# 124  fixate1  420   0.6  YUWEI  ytu029     4  0.849400  0.935583      -10.0
# 51   fixate1  420   0.6  YUWEI  clu221     3  0.825895  0.900849       -8.0
# 28   fixate1  420   0.6  YUWEI  clu116     0  0.821391  0.835483       -6.0
# 72   fixate1  420   0.6  YUWEI  clu267     7  0.818134  0.955361        0.0
# ..       ...  ...   ...    ...     ...   ...       ...       ...        ...
# 38   fixate1  420   0.6  YUWEI  clu180     0  0.126446       NaN       -4.0
# 96   fixate1  420   0.6  YUWEI  clu294     2  0.118799       NaN       -4.0
# 97   fixate1  420   0.6  YUWEI  clu294     3  0.079331       NaN       -4.0
# 13   fixate1  420   0.6  YUWEI  clu069     0  0.063656       NaN       -2.0
# 102  fixate1  420   0.6  YUWEI  clu294     9  0.047721       NaN       -6.0
#
#      best_lag
# 42          2
# 124         4
# 51          3
# 28          3
# 72          4
# ..        ...
# 38         12
# 96         11
# 97          9
# 13          4
# 102         8
#
# [141 rows x 10 columns]

# %% [markdown]
# ### $\beta = 0.4$

# %%
fit_name = 'vanilla_fixate1_nf-420_beta-0.4_(2023_05_11,19:25)'
df, df_all, ro_all, args, tr = summarize_neural_fits(fit_name)

_ = show_neural_results(df)
len(df)
# Out:
# 141

# %%
inds = df['perf'].argsort()[::-1]
df.iloc[inds]
# Out:
#     category   nf  beta   root    expt  cell      perf  max_perf  log_alpha  \
# 124  fixate1  420   0.4  YUWEI  ytu029     4  0.900714  0.935583       -1.0
# 29   fixate1  420   0.4  YUWEI  clu120     0  0.886863  0.967720       -4.0
# 42   fixate1  420   0.4  YUWEI  clu209     1  0.882197  0.923722       -1.0
# 69   fixate1  420   0.4  YUWEI  clu267     4  0.878913  0.979806      -10.0
# 51   fixate1  420   0.4  YUWEI  clu221     3  0.874686  0.900849       -2.0
# ..       ...  ...   ...    ...     ...   ...       ...       ...        ...
# 97   fixate1  420   0.4  YUWEI  clu294     3  0.075401       NaN        0.0
# 102  fixate1  420   0.4  YUWEI  clu294     9  0.068862       NaN       -1.0
# 31   fixate1  420   0.4  YUWEI  clu131     0  0.059507  0.843686      -10.0
# 34   fixate1  420   0.4  YUWEI  clu145     0 -0.002516  0.593791        2.0
# 130  fixate1  420   0.4  YUWEI  ytu029    12 -0.049515  0.324496        0.0
#
#      best_lag
# 124         3
# 29          4
# 42          3
# 69          3
# 51          4
# ..        ...
# 97          6
# 102         3
# 31          2
# 34         12
# 130         0
#
# [141 rows x 10 columns]

# %% [markdown]
# ### $\beta = 10$

# %%
fit_name = 'vanilla_fixate1_nf-420_beta-10.0_(2023_05_09,09:59)'
df, df_all, ro_all, args, tr = summarize_neural_fits(fit_name)

_ = show_neural_results(df)
len(df)
# Out:
# 141

# %%
inds = df['perf'].argsort()[::-1]
df.iloc[inds]
# Out:
#     category   nf  beta   root    expt  cell      perf  max_perf  log_alpha  \
# 42   fixate1  420  10.0  YUWEI  clu209     1  0.896120  0.923722       -4.0
# 51   fixate1  420  10.0  YUWEI  clu221     3  0.853357  0.900849      -10.0
# 43   fixate1  420  10.0  YUWEI  clu209     4  0.830650  0.933615       -4.0
# 109  fixate1  420  10.0  YUWEI  clu295     4  0.829844  0.929612       -8.0
# 50   fixate1  420  10.0  YUWEI  clu221     2  0.817239  0.921324      -10.0
# ..       ...  ...   ...    ...     ...   ...       ...       ...        ...
# 96   fixate1  420  10.0  YUWEI  clu294     2  0.111811       NaN       -4.0
# 34   fixate1  420  10.0  YUWEI  clu145     0  0.107673  0.593791        0.0
# 97   fixate1  420  10.0  YUWEI  clu294     3  0.067694       NaN       -4.0
# 13   fixate1  420  10.0  YUWEI  clu069     0  0.065041       NaN       -4.0
# 102  fixate1  420  10.0  YUWEI  clu294     9  0.042231       NaN       -6.0
#
#      best_lag
# 42          4
# 51          4
# 43          3
# 109         4
# 50          4
# ..        ...
# 96         12
# 34          0
# 97          0
# 13          4
# 102         1
#
# [141 rows x 10 columns]

# %% [markdown]
# ### $\beta = 2$

# %%
fit_name = 'vanilla_fixate1_nf-420_beta-2.0_(2023_05_09,08:19)'
df, df_all, ro_all, args, tr = summarize_neural_fits(fit_name)

_ = show_neural_results(df)
len(df)
# Out:
# 141

# %%
inds = df['perf'].argsort()[::-1]
df.iloc[inds]
# Out:
#     category   nf  beta   root    expt  cell      perf  max_perf  log_alpha  \
# 42   fixate1  420   2.0  YUWEI  clu209     1  0.905538  0.923722       -4.0
# 43   fixate1  420   2.0  YUWEI  clu209     4  0.847234  0.933615       -6.0
# 19   fixate1  420   2.0  YUWEI  clu090     0  0.817957  0.990020       -4.0
# 109  fixate1  420   2.0  YUWEI  clu295     4  0.817220  0.929612       -6.0
# 41   fixate1  420   2.0  YUWEI  clu209     0  0.813111  0.896802       -4.0
# ..       ...  ...   ...    ...     ...   ...       ...       ...        ...
# 96   fixate1  420   2.0  YUWEI  clu294     2  0.118471       NaN       -4.0
# 103  fixate1  420   2.0  YUWEI  clu294    10  0.116947       NaN       -4.0
# 97   fixate1  420   2.0  YUWEI  clu294     3  0.065444       NaN       -4.0
# 13   fixate1  420   2.0  YUWEI  clu069     0  0.061682       NaN       -4.0
# 102  fixate1  420   2.0  YUWEI  clu294     9  0.048468       NaN       -6.0
#
#      best_lag
# 42          4
# 43          4
# 19          2
# 109         4
# 41          5
# ..        ...
# 96         10
# 103         3
# 97         10
# 13          3
# 102         0
#
# [141 rows x 10 columns]

# %% [markdown]
# ### $\beta = 1$

# %%
fit_name = 'vanilla_fixate1_nf-420_beta-1.0_(2023_05_07,01:18)'
df, df_all, ro_all, args, tr = summarize_neural_fits(fit_name)

_ = show_neural_results(df)
len(df)
# Out:
# 141

# %%
inds = df['perf'].argsort()[::-1]
df.iloc[inds]
# Out:
#     category   nf  beta   root    expt  cell      perf  max_perf  log_alpha  \
# 42   fixate1  420   1.0  YUWEI  clu209     1  0.893502  0.923722       -6.0
# 51   fixate1  420   1.0  YUWEI  clu221     3  0.849253  0.900849       -1.0
# 43   fixate1  420   1.0  YUWEI  clu209     4  0.843770  0.933615       -4.0
# 69   fixate1  420   1.0  YUWEI  clu267     4  0.828408  0.979806       -8.0
# 49   fixate1  420   1.0  YUWEI  clu221     1  0.828386  0.924544       -4.0
# ..       ...  ...   ...    ...     ...   ...       ...       ...        ...
# 103  fixate1  420   1.0  YUWEI  clu294    10  0.115307       NaN       -4.0
# 130  fixate1  420   1.0  YUWEI  ytu029    12  0.093452  0.324496        0.0
# 97   fixate1  420   1.0  YUWEI  clu294     3  0.068787       NaN       -2.0
# 13   fixate1  420   1.0  YUWEI  clu069     0  0.064196       NaN       -4.0
# 102  fixate1  420   1.0  YUWEI  clu294     9  0.053824       NaN       -4.0
#
#      best_lag
# 42          4
# 51          3
# 43          2
# 69          5
# 49          3
# ..        ...
# 103        12
# 130         9
# 97          8
# 13          4
# 102         0
#
# [141 rows x 10 columns]

# %% [markdown]
# ### $\beta = 0.5$

# %%
fit_name = 'vanilla_fixate1_nf-420_beta-0.5_(2023_05_07,02:51)'
df, df_all, ro_all, args, tr = summarize_neural_fits(fit_name)

_ = show_neural_results(df)
len(df)
# Out:
# 141

# %%
inds = df['perf'].argsort()[::-1]
df.iloc[inds]
# Out:
#     category   nf  beta   root    expt  cell      perf  max_perf  log_alpha  \
# 51   fixate1  420   0.5  YUWEI  clu221     3  0.887011  0.900849       -2.0
# 28   fixate1  420   0.5  YUWEI  clu116     0  0.883898  0.835483      -10.0
# 42   fixate1  420   0.5  YUWEI  clu209     1  0.881716  0.923722        0.0
# 69   fixate1  420   0.5  YUWEI  clu267     4  0.875058  0.979806       -2.0
# 109  fixate1  420   0.5  YUWEI  clu295     4  0.859810  0.929612       -2.0
# ..       ...  ...   ...    ...     ...   ...       ...       ...        ...
# 96   fixate1  420   0.5  YUWEI  clu294     2  0.107527       NaN       -1.0
# 103  fixate1  420   0.5  YUWEI  clu294    10  0.107469       NaN       -2.0
# 13   fixate1  420   0.5  YUWEI  clu069     0  0.076600       NaN       -1.0
# 97   fixate1  420   0.5  YUWEI  clu294     3  0.058739       NaN       -1.0
# 102  fixate1  420   0.5  YUWEI  clu294     9  0.053966       NaN       -2.0
#
#      best_lag
# 51          4
# 28          3
# 42          4
# 69          4
# 109         5
# ..        ...
# 96         11
# 103         2
# 13          4
# 97          0
# 102         4
#
# [141 rows x 10 columns]

# %% [markdown]
# ## Fixate 0

# %% [markdown]
# ### $\beta = 10$

# %%
fit_name = 'fixate0_nf-280_beta-10.0_(2023_05_07,04:49)'
df, df_all, ro_all, args, tr = summarize_neural_fits(fit_name)

_ = show_neural_results(df)
len(df)
# Out:
# 141

# %%
inds = df['perf'].argsort()[::-1]
df.iloc[inds]
# Out:
#     category   nf  beta   root    expt  cell      perf  max_perf  log_alpha  \
# 118  fixate0  280  10.0  YUWEI  ytu028     8  0.882526  0.328052       -4.0
# 67   fixate0  280  10.0  YUWEI  clu267     1  0.863390  0.944895      -10.0
# 124  fixate0  280  10.0  YUWEI  ytu029     4  0.857094  0.935583        2.0
# 28   fixate0  280  10.0  YUWEI  clu116     0  0.850000  0.835483      -10.0
# 54   fixate0  280  10.0  YUWEI  clu222     0  0.819592  0.969344      -10.0
# ..       ...  ...   ...    ...     ...   ...       ...       ...        ...
# 96   fixate0  280  10.0  YUWEI  clu294     2  0.077073       NaN      -10.0
# 103  fixate0  280  10.0  YUWEI  clu294    10  0.074726       NaN        1.0
# 13   fixate0  280  10.0  YUWEI  clu069     0  0.056115       NaN      -10.0
# 102  fixate0  280  10.0  YUWEI  clu294     9  0.040841       NaN        2.0
# 97   fixate0  280  10.0  YUWEI  clu294     3  0.031083       NaN        2.0
#
#      best_lag
# 118         7
# 67          8
# 124         5
# 28          3
# 54          0
# ..        ...
# 96         12
# 103         7
# 13          5
# 102         0
# 97          5
#
# [141 rows x 10 columns]

# %% [markdown]
# ### $\beta = 5$

# %%
fit_name = 'fixate0_nf-280_beta-5.0_(2023_05_07,09:58)'
df, df_all, ro_all, args, tr = summarize_neural_fits(fit_name)

_ = show_neural_results(df)
len(df)
# Out:
# 141

# %%
inds = df['perf'].argsort()[::-1]
df.iloc[inds]
# Out:
#     category   nf  beta   root    expt  cell      perf  max_perf  log_alpha  \
# 49   fixate0  280   5.0  YUWEI  clu221     1  0.877971  0.924544       -4.0
# 51   fixate0  280   5.0  YUWEI  clu221     3  0.877300  0.900849       -8.0
# 42   fixate0  280   5.0  YUWEI  clu209     1  0.862654  0.923722       -2.0
# 109  fixate0  280   5.0  YUWEI  clu295     4  0.849435  0.929612       -2.0
# 111  fixate0  280   5.0  YUWEI  clu295     8  0.837366  0.987233       -2.0
# ..       ...  ...   ...    ...     ...   ...       ...       ...        ...
# 103  fixate0  280   5.0  YUWEI  clu294    10  0.098548       NaN      -10.0
# 96   fixate0  280   5.0  YUWEI  clu294     2  0.075088       NaN      -10.0
# 13   fixate0  280   5.0  YUWEI  clu069     0  0.051655       NaN        2.0
# 102  fixate0  280   5.0  YUWEI  clu294     9  0.051246       NaN       -6.0
# 97   fixate0  280   5.0  YUWEI  clu294     3  0.050747       NaN        4.0
#
#      best_lag
# 49          7
# 51          4
# 42          4
# 109         4
# 111         4
# ..        ...
# 103         2
# 96          4
# 13          4
# 102         1
# 97          4
#
# [141 rows x 10 columns]

# %% [markdown]
# ### $\beta = 2$

# %%
fit_name = 'fixate0_nf-280_beta-2.0_(2023_05_07,04:16)'
df, df_all, ro_all, args, tr = summarize_neural_fits(fit_name)

_ = show_neural_results(df)
len(df)
# Out:
# 141

# %%
inds = df['perf'].argsort()[::-1]
df.iloc[inds]
# Out:
#     category   nf  beta   root    expt  cell      perf  max_perf  log_alpha  \
# 28   fixate0  280   2.0  YUWEI  clu116     0  0.868261  0.835483       -4.0
# 51   fixate0  280   2.0  YUWEI  clu221     3  0.861644  0.900849        1.0
# 42   fixate0  280   2.0  YUWEI  clu209     1  0.861356  0.923722        3.0
# 43   fixate0  280   2.0  YUWEI  clu209     4  0.840085  0.933615        1.0
# 69   fixate0  280   2.0  YUWEI  clu267     4  0.835492  0.979806        2.0
# ..       ...  ...   ...    ...     ...   ...       ...       ...        ...
# 96   fixate0  280   2.0  YUWEI  clu294     2  0.074922       NaN        3.0
# 13   fixate0  280   2.0  YUWEI  clu069     0  0.074834       NaN        3.0
# 102  fixate0  280   2.0  YUWEI  clu294     9  0.045698       NaN      -10.0
# 97   fixate0  280   2.0  YUWEI  clu294     3  0.035442       NaN       12.0
# 130  fixate0  280   2.0  YUWEI  ytu029    12  0.025017  0.324496        4.0
#
#      best_lag
# 28          2
# 51          4
# 42          3
# 43          4
# 69          5
# ..        ...
# 96          1
# 13          4
# 102         8
# 97         11
# 130        11
#
# [141 rows x 10 columns]

# %% [markdown]
# ### $\beta = 1$

# %%
fit_name = 'fixate0_nf-280_beta-1.0_(2023_05_08,15:10)'
df, df_all, ro_all, args, tr = summarize_neural_fits(fit_name)

_ = show_neural_results(df)
len(df)
# Out:
# 141

# %%
inds = df['perf'].argsort()[::-1]
df.iloc[inds]
# Out:
#     category   nf  beta   root    expt  cell      perf  max_perf  log_alpha  \
# 42   fixate0  280   1.0  YUWEI  clu209     1  0.836599  0.923722        1.0
# 23   fixate0  280   1.0  YUWEI  clu104     0  0.833890  0.980831       12.0
# 69   fixate0  280   1.0  YUWEI  clu267     4  0.824602  0.979806       -1.0
# 51   fixate0  280   1.0  YUWEI  clu221     3  0.817168  0.900849        4.0
# 28   fixate0  280   1.0  YUWEI  clu116     0  0.816366  0.835483       -1.0
# ..       ...  ...   ...    ...     ...   ...       ...       ...        ...
# 96   fixate0  280   1.0  YUWEI  clu294     2  0.071317       NaN        2.0
# 13   fixate0  280   1.0  YUWEI  clu069     0  0.070164       NaN       -1.0
# 31   fixate0  280   1.0  YUWEI  clu131     0  0.055131  0.843686       12.0
# 102  fixate0  280   1.0  YUWEI  clu294     9  0.053843       NaN        6.0
# 97   fixate0  280   1.0  YUWEI  clu294     3  0.021481       NaN       10.0
#
#      best_lag
# 42          4
# 23          4
# 69          4
# 51          2
# 28          2
# ..        ...
# 96          8
# 13          4
# 31          1
# 102         0
# 97         12
#
# [141 rows x 10 columns]

# %% [markdown]
# ### $\beta = 1$ (small)

# %%
# fit_name = 'fixate0_nf-80_beta-1_(2023_05_04,09:03)'
df, df_all, ro_all, args, tr = summarize_neural_fits(fit_name)

_ = show_neural_results(df)
len(df)
# Out:
# 141

# %%
inds = df['perf'].argsort()[::-1]
df.iloc[inds]
# Out:
#     category  nf  beta   root    expt  cell      perf  max_perf  log_alpha  \
# 19   fixate0  80   1.0  YUWEI  clu090     0  0.822292  0.990020        0.0
# 28   fixate0  80   1.0  YUWEI  clu116     0  0.811698  0.835483        2.0
# 54   fixate0  80   1.0  YUWEI  clu222     0  0.769233  0.969344       -6.0
# 70   fixate0  80   1.0  YUWEI  clu267     5  0.760665  0.984911       -6.0
# 20   fixate0  80   1.0  YUWEI  clu095     0  0.754663  0.956606        3.0
# ..       ...  ..   ...    ...     ...   ...       ...       ...        ...
# 97   fixate0  80   1.0  YUWEI  clu294     3  0.029146       NaN       10.0
# 66   fixate0  80   1.0  YUWEI  clu229    11  0.025399  0.716168        5.0
# 61   fixate0  80   1.0  YUWEI  clu225     0  0.019836  0.791217      -10.0
# 31   fixate0  80   1.0  YUWEI  clu131     0 -0.021731  0.843686        4.0
# 118  fixate0  80   1.0  YUWEI  ytu028     8 -0.108443  0.328052        2.0
#
#      best_lag
# 19          2
# 28          2
# 54          1
# 70          5
# 20          3
# ..        ...
# 97          0
# 66          0
# 61         11
# 31          9
# 118        12
#
# [141 rows x 10 columns]

# %% [markdown]
# ## Obj 1

# %% [markdown]
# ### $\beta = 10.0$

# %%
# fit_name = 'obj1_nf-140_beta-10.0_(2023_05_04,11:53)'
df, df_all, ro_all, args, tr = summarize_neural_fits(fit_name)

_ = show_neural_results(df)
len(df)
# Out:
# 141

# %%
inds = df['perf'].argsort()[::-1]
df.iloc[inds]
# Out:
#     category   nf  beta   root    expt  cell      perf  max_perf  log_alpha  \
# 118     obj1  140  10.0  YUWEI  ytu028     8  0.922303  0.328052        1.0
# 40      obj1  140  10.0  YUWEI  clu183     0  0.886864  0.927126        2.0
# 70      obj1  140  10.0  YUWEI  clu267     5  0.825451  0.984911        1.0
# 124     obj1  140  10.0  YUWEI  ytu029     4  0.820556  0.935583        1.0
# 43      obj1  140  10.0  YUWEI  clu209     4  0.786207  0.933615        0.0
# ..       ...  ...   ...    ...     ...   ...       ...       ...        ...
# 96      obj1  140  10.0  YUWEI  clu294     2  0.065607       NaN      -10.0
# 10      obj1  140  10.0  YUWEI  clu061     0  0.058620       NaN      -10.0
# 102     obj1  140  10.0  YUWEI  clu294     9  0.035251       NaN       -1.0
# 97      obj1  140  10.0  YUWEI  clu294     3  0.032923       NaN        6.0
# 13      obj1  140  10.0  YUWEI  clu069     0  0.031040       NaN      -10.0
#
#      best_lag
# 118         8
# 40          4
# 70          6
# 124         4
# 43          6
# ..        ...
# 96         12
# 10         11
# 102         3
# 97          6
# 13          5
#
# [141 rows x 10 columns]

# %% [markdown]
# ### $\beta = 0.5$

# %%
fit_name = 'obj1_nf-280_beta-0.5_(2023_05_04,11:11)'
df, df_all, ro_all, args, tr = summarize_neural_fits(fit_name)

_ = show_neural_results(df)
len(df)
# Out:
# 141

# %%
inds = df['perf'].argsort()[::-1]
df.iloc[inds]
# Out:
#     category   nf  beta   root    expt  cell      perf  max_perf  log_alpha  \
# 28      obj1  280   0.5  YUWEI  clu116     0  0.837850  0.835483       16.0
# 67      obj1  280   0.5  YUWEI  clu267     1  0.831336  0.944895       -2.0
# 42      obj1  280   0.5  YUWEI  clu209     1  0.823877  0.923722        5.0
# 69      obj1  280   0.5  YUWEI  clu267     4  0.823590  0.979806        4.0
# 109     obj1  280   0.5  YUWEI  clu295     4  0.815383  0.929612        2.0
# ..       ...  ...   ...    ...     ...   ...       ...       ...        ...
# 96      obj1  280   0.5  YUWEI  clu294     2  0.110499       NaN        6.0
# 97      obj1  280   0.5  YUWEI  clu294     3  0.083910       NaN        6.0
# 13      obj1  280   0.5  YUWEI  clu069     0  0.075498       NaN        6.0
# 34      obj1  280   0.5  YUWEI  clu145     0  0.069567  0.593791        8.0
# 102     obj1  280   0.5  YUWEI  clu294     9  0.059685       NaN        6.0
#
#      best_lag
# 28          0
# 67          9
# 42          2
# 69          4
# 109         5
# ..        ...
# 96          0
# 97          0
# 13          4
# 34          0
# 102         3
#
# [141 rows x 10 columns]

# %% [markdown]
# ### $\beta = 1.0$

# %%
fit_name = 'obj1_nf-280_beta-1.0_(2023_05_04,10:27)'
df, df_all, ro_all, args, tr = summarize_neural_fits(fit_name)

_ = show_neural_results(df)
len(df)
# Out:
# 141

# %%
inds = df['perf'].argsort()[::-1]
df.iloc[inds]
# Out:
#     category   nf  beta   root    expt  cell      perf  max_perf  log_alpha  \
# 118     obj1  280   1.0  YUWEI  ytu028     8  0.982281  0.328052       -2.0
# 42      obj1  280   1.0  YUWEI  clu209     1  0.918254  0.923722      -10.0
# 51      obj1  280   1.0  YUWEI  clu221     3  0.834817  0.900849      -10.0
# 109     obj1  280   1.0  YUWEI  clu295     4  0.827101  0.929612      -10.0
# 43      obj1  280   1.0  YUWEI  clu209     4  0.791167  0.933615        0.0
# ..       ...  ...   ...    ...     ...   ...       ...       ...        ...
# 103     obj1  280   1.0  YUWEI  clu294    10  0.102135       NaN      -10.0
# 96      obj1  280   1.0  YUWEI  clu294     2  0.084034       NaN        1.0
# 97      obj1  280   1.0  YUWEI  clu294     3  0.067822       NaN        1.0
# 13      obj1  280   1.0  YUWEI  clu069     0  0.055478       NaN      -10.0
# 102     obj1  280   1.0  YUWEI  clu294     9  0.053283       NaN      -10.0
#
#      best_lag
# 118         6
# 42          4
# 51          4
# 109         5
# 43          3
# ..        ...
# 103         4
# 96          9
# 97          3
# 13          4
# 102         6
#
# [141 rows x 10 columns]

# %% [markdown]
# ### $\beta = 1.0$ (nf = 140)

# %%
# fit_name = 'obj1_nf-140_beta-1_(2023_05_02,15:57)'
df, df_all, ro_all, args, tr = summarize_neural_fits(fit_name)

_ = show_neural_results(df)
len(df)
# Out:
# 141

# %%
inds = df['perf'].argsort()[::-1]
df.iloc[inds]
# Out:
#     category   nf  beta   root    expt  cell      perf  max_perf  log_alpha  \
# 42      obj1  140   1.0  YUWEI  clu209     1  0.837109  0.923722        2.0
# 28      obj1  140   1.0  YUWEI  clu116     0  0.786949  0.835483       -4.0
# 21      obj1  140   1.0  YUWEI  clu096     0  0.784371  0.909688       -1.0
# 19      obj1  140   1.0  YUWEI  clu090     0  0.765962  0.990020        6.0
# 24      obj1  140   1.0  YUWEI  clu107     0  0.750969  0.970653        0.0
# ..       ...  ...   ...    ...     ...   ...       ...       ...        ...
# 48      obj1  140   1.0  YUWEI  clu216     0  0.078946  0.896978       -2.0
# 102     obj1  140   1.0  YUWEI  clu294     9  0.066947       NaN        2.0
# 13      obj1  140   1.0  YUWEI  clu069     0  0.062923       NaN        5.0
# 31      obj1  140   1.0  YUWEI  clu131     0  0.050162  0.843686        4.0
# 40      obj1  140   1.0  YUWEI  clu183     0 -0.011984  0.927126       -6.0
#
#      best_lag
# 42          3
# 28          3
# 21          2
# 19          2
# 24          4
# ..        ...
# 48         12
# 102         3
# 13          4
# 31          0
# 40         12
#
# [141 rows x 10 columns]

# %% [markdown]
# ## Transl 1

# %% [markdown]
# ### $\beta = 5$

# %%
fit_name = 'transl1_nf-420_beta-5.0_(2023_05_15,16:32)'
df, df_all, ro_all, args, tr = summarize_neural_fits(fit_name)

_ = show_neural_results(df)
len(df)
# Out:
# 141

# %%
inds = df['perf'].argsort()[::-1]
df.iloc[inds]
# Out:
#     category   nf  beta   root    expt  cell      perf  max_perf  log_alpha  \
# 42   transl1  420   5.0  YUWEI  clu209     1  0.860603  0.923722      -10.0
# 49   transl1  420   5.0  YUWEI  clu221     1  0.822304  0.924544      -10.0
# 43   transl1  420   5.0  YUWEI  clu209     4  0.821550  0.933615      -10.0
# 109  transl1  420   5.0  YUWEI  clu295     4  0.782099  0.929612      -10.0
# 69   transl1  420   5.0  YUWEI  clu267     4  0.781933  0.979806      -10.0
# ..       ...  ...   ...    ...     ...   ...       ...       ...        ...
# 103  transl1  420   5.0  YUWEI  clu294    10  0.088269       NaN        1.0
# 96   transl1  420   5.0  YUWEI  clu294     2  0.086094       NaN        1.0
# 97   transl1  420   5.0  YUWEI  clu294     3  0.053487       NaN        1.0
# 13   transl1  420   5.0  YUWEI  clu069     0  0.050053       NaN        2.0
# 102  transl1  420   5.0  YUWEI  clu294     9  0.049154       NaN        1.0
#
#      best_lag
# 42          4
# 49          4
# 43          4
# 109         4
# 69          6
# ..        ...
# 103         2
# 96          6
# 97          1
# 13         12
# 102         6
#
# [141 rows x 10 columns]

# %% [markdown]
# ### $\beta = 10.0$

# %%
fit_name = 'transl1_nf-420_beta-10.0_(2023_05_04,09:20)'
df, df_all, ro_all, args, tr = summarize_neural_fits(fit_name)

_ = show_neural_results(df)
len(df)
# Out:
# 141

# %%
inds = df['perf'].argsort()[::-1]
df.iloc[inds]
# Out:
#     category   nf  beta   root    expt  cell      perf  max_perf  log_alpha  \
# 118  transl1  420  10.0  YUWEI  ytu028     8  0.926081  0.328052        1.0
# 42   transl1  420  10.0  YUWEI  clu209     1  0.888798  0.923722      -10.0
# 50   transl1  420  10.0  YUWEI  clu221     2  0.878807  0.921324      -10.0
# 28   transl1  420  10.0  YUWEI  clu116     0  0.859043  0.835483      -10.0
# 131  transl1  420  10.0  YUWEI  ytu029    13  0.853619  0.267459        3.0
# ..       ...  ...   ...    ...     ...   ...       ...       ...        ...
# 0    transl1  420  10.0  YUWEI  clu036     0  0.106150       NaN      -10.0
# 103  transl1  420  10.0  YUWEI  clu294    10  0.093615       NaN      -10.0
# 97   transl1  420  10.0  YUWEI  clu294     3  0.085758       NaN        1.0
# 102  transl1  420  10.0  YUWEI  clu294     9  0.057166       NaN        1.0
# 13   transl1  420  10.0  YUWEI  clu069     0  0.054477       NaN        2.0
#
#      best_lag
# 118         9
# 42          3
# 50          4
# 28          3
# 131         2
# ..        ...
# 0           3
# 103         5
# 97          4
# 102         8
# 13          2
#
# [141 rows x 10 columns]

# %% [markdown]
# ### $\beta = 1.0$

# %%
fit_name = 'transl1_nf-420_beta-1.0_(2023_05_02,22:02)'
df, df_all, ro_all, args, tr = summarize_neural_fits(fit_name)

_ = show_neural_results(df)
len(df)
# Out:
# 141

# %%
inds = df['perf'].argsort()[::-1]
df.iloc[inds]
# Out:
#     category   nf  beta   root    expt  cell      perf  max_perf  log_alpha  \
# 118  transl1  420   1.0  YUWEI  ytu028     8  0.937899  0.328052       -8.0
# 42   transl1  420   1.0  YUWEI  clu209     1  0.860165  0.923722        2.0
# 124  transl1  420   1.0  YUWEI  ytu029     4  0.842731  0.935583       -6.0
# 67   transl1  420   1.0  YUWEI  clu267     1  0.824497  0.944895      -10.0
# 43   transl1  420   1.0  YUWEI  clu209     4  0.820370  0.933615        0.0
# ..       ...  ...   ...    ...     ...   ...       ...       ...        ...
# 96   transl1  420   1.0  YUWEI  clu294     2  0.104609       NaN        1.0
# 103  transl1  420   1.0  YUWEI  clu294    10  0.102957       NaN        1.0
# 97   transl1  420   1.0  YUWEI  clu294     3  0.068029       NaN        2.0
# 13   transl1  420   1.0  YUWEI  clu069     0  0.060499       NaN        5.0
# 102  transl1  420   1.0  YUWEI  clu294     9  0.040505       NaN      -10.0
#
#      best_lag
# 118         7
# 42          2
# 124         6
# 67          6
# 43          3
# ..        ...
# 96          8
# 103         4
# 97          0
# 13          3
# 102         6
#
# [141 rows x 10 columns]

# %% [markdown]
# ### $\beta = 0.5$

# %%
fit_name = 'transl1_nf-420_beta-0.5_(2023_05_02,15:00)'
df, df_all, ro_all, args, tr = summarize_neural_fits(fit_name)

_ = show_neural_results(df)
len(df)
# Out:
# 141

# %%
inds = df['perf'].argsort()[::-1]
df.iloc[inds]
# Out:
#     category   nf  beta   root    expt  cell      perf  max_perf  log_alpha  \
# 124  transl1  420   0.5  YUWEI  ytu029     4  0.908100  0.935583       -4.0
# 29   transl1  420   0.5  YUWEI  clu120     0  0.884341  0.967720        4.0
# 69   transl1  420   0.5  YUWEI  clu267     4  0.875584  0.979806        3.0
# 42   transl1  420   0.5  YUWEI  clu209     1  0.875578  0.923722       -2.0
# 28   transl1  420   0.5  YUWEI  clu116     0  0.849563  0.835483        3.0
# ..       ...  ...   ...    ...     ...   ...       ...       ...        ...
# 103  transl1  420   0.5  YUWEI  clu294    10  0.133499       NaN        4.0
# 96   transl1  420   0.5  YUWEI  clu294     2  0.125624       NaN        5.0
# 97   transl1  420   0.5  YUWEI  clu294     3  0.090922       NaN        6.0
# 13   transl1  420   0.5  YUWEI  clu069     0  0.075240       NaN        5.0
# 102  transl1  420   0.5  YUWEI  clu294     9  0.057947       NaN        4.0
#
#      best_lag
# 124         3
# 29          3
# 69          5
# 42          4
# 28          2
# ..        ...
# 103         3
# 96          7
# 97          6
# 13          4
# 102         3
#
# [141 rows x 10 columns]

# %% [markdown]
# ## Fixate 1

# %% [markdown]
# ### $\beta = 0.6$

# %%
fit_name = 'fixate1_nf-420_beta-0.6_(2023_04_30,20:36)'
df, df_all, ro_all, args, tr = summarize_neural_fits(fit_name)

_ = show_neural_results(df)
len(df)
# Out:
# 141

# %%
inds = df['perf'].argsort()[::-1]
df.iloc[inds]
# Out:
#     category   nf  beta   root    expt  cell      perf  max_perf  log_alpha  \
# 42   fixate1  420   0.6  YUWEI  clu209     1  0.905758  0.923722        3.0
# 29   fixate1  420   0.6  YUWEI  clu120     0  0.874993  0.967720        0.0
# 72   fixate1  420   0.6  YUWEI  clu267     7  0.856259  0.955361      -10.0
# 124  fixate1  420   0.6  YUWEI  ytu029     4  0.852892  0.935583        4.0
# 69   fixate1  420   0.6  YUWEI  clu267     4  0.847146  0.979806        1.0
# ..       ...  ...   ...    ...     ...   ...       ...       ...        ...
# 103  fixate1  420   0.6  YUWEI  clu294    10  0.130683       NaN        4.0
# 96   fixate1  420   0.6  YUWEI  clu294     2  0.130189       NaN        5.0
# 97   fixate1  420   0.6  YUWEI  clu294     3  0.093309       NaN        6.0
# 13   fixate1  420   0.6  YUWEI  clu069     0  0.084369       NaN        5.0
# 102  fixate1  420   0.6  YUWEI  clu294     9  0.063530       NaN        6.0
#
#      best_lag
# 42          3
# 29          3
# 72          4
# 124         3
# 69          5
# ..        ...
# 103         4
# 96          6
# 97          2
# 13          4
# 102         1
#
# [141 rows x 10 columns]

# %% [markdown]
# ### $\beta = 0.7$

# %%
fit_name = 'fixate1_nf-420_beta-0.7_(2023_04_30,21:40)'
df, df_all, ro_all, args, tr = summarize_neural_fits(fit_name)

_ = show_neural_results(df)
len(df)
# Out:
# 141

# %%
inds = df['perf'].argsort()[::-1]
df.iloc[inds]
# Out:
#     category   nf  beta   root    expt  cell      perf  max_perf  log_alpha  \
# 42   fixate1  420   0.7  YUWEI  clu209     1  0.867432  0.923722        4.0
# 124  fixate1  420   0.7  YUWEI  ytu029     4  0.867288  0.935583        4.0
# 28   fixate1  420   0.7  YUWEI  clu116     0  0.855247  0.835483        1.0
# 69   fixate1  420   0.7  YUWEI  clu267     4  0.851329  0.979806        3.0
# 109  fixate1  420   0.7  YUWEI  clu295     4  0.835850  0.929612       -6.0
# ..       ...  ...   ...    ...     ...   ...       ...       ...        ...
# 68   fixate1  420   0.7  YUWEI  clu267     3  0.119581  0.943782        5.0
# 97   fixate1  420   0.7  YUWEI  clu294     3  0.091513       NaN        6.0
# 13   fixate1  420   0.7  YUWEI  clu069     0  0.082509       NaN        5.0
# 102  fixate1  420   0.7  YUWEI  clu294     9  0.065941       NaN       -2.0
# 34   fixate1  420   0.7  YUWEI  clu145     0  0.042415  0.593791       -8.0
#
#      best_lag
# 42          4
# 124         3
# 28          3
# 69          5
# 109         3
# ..        ...
# 68          6
# 97          1
# 13          4
# 102         4
# 34          3
#
# [141 rows x 10 columns]

# %% [markdown]
# ### $\beta = 10$

# %%
fit_name = 'fixate1_nf-420_beta-10.0_(2023_04_30,22:48)'
df, df_all, ro_all, args, tr = summarize_neural_fits(fit_name)

_ = show_neural_results(df)
len(df)
# Out:
# 141

# %%
inds = df['perf'].argsort()[::-1]
df.iloc[inds]
# Out:
#     category   nf  beta   root    expt  cell      perf  max_perf  log_alpha  \
# 124  fixate1  420  10.0  YUWEI  ytu029     4  0.867450  0.935583        0.0
# 51   fixate1  420  10.0  YUWEI  clu221     3  0.852781  0.900849        2.0
# 28   fixate1  420  10.0  YUWEI  clu116     0  0.844301  0.835483       -2.0
# 49   fixate1  420  10.0  YUWEI  clu221     1  0.818352  0.924544        2.0
# 29   fixate1  420  10.0  YUWEI  clu120     0  0.816611  0.967720        4.0
# ..       ...  ...   ...    ...     ...   ...       ...       ...        ...
# 103  fixate1  420  10.0  YUWEI  clu294    10  0.085266       NaN      -10.0
# 13   fixate1  420  10.0  YUWEI  clu069     0  0.061334       NaN      -10.0
# 96   fixate1  420  10.0  YUWEI  clu294     2  0.049240       NaN      -10.0
# 97   fixate1  420  10.0  YUWEI  clu294     3  0.041724       NaN        6.0
# 102  fixate1  420  10.0  YUWEI  clu294     9  0.038987       NaN      -10.0
#
#      best_lag
# 124         4
# 51          4
# 28          2
# 49          4
# 29          3
# ..        ...
# 103         3
# 13          4
# 96         11
# 97          6
# 102         2
#
# [141 rows x 10 columns]
