# %% [markdown]
# # (01) Neural $\beta$ results (GABAN)
#
# **Motivation**: Fits on GABAN <br>

# %%
# HIDE CODE


import os, sys
from IPython.display import display

# tmp & extras dir
git_dir = os.path.join(os.environ['HOME'], 'Dropbox/git')
extras_dir = os.path.join(git_dir, 'jb-MTMST/_extras')
fig_base_dir = os.path.join(git_dir, 'jb-MTMST/figs')
tmp_dir = os.path.join(git_dir, 'jb-MTMST/tmp')

# GitHub
sys.path.insert(0, os.path.join(git_dir, '_MTMST'))
from vae.train_vae import TrainerVAE, ConfigTrainVAE
from vae.vae2d import VAE, ConfigVAE
from figures.fighelper import *
from analysis.glm import *


# warnings, tqdm, & style
warnings.filterwarnings('ignore', category=DeprecationWarning)
from rich.jupyter import print
# %matplotlib inline
set_style()

# %%
fits = [
    'fixate1_k-32_z-20x[3,6,12]_enc(1x3)-dec(1x2)-pre(1x3)-post(1x3)/ep160-b600-lr(0.002)_beta(0.6:0x0.5)_lamb(0.0001)_gr(250.0)_(2023_04_29,17:53)',
    'fixate1_k-32_z-20x[3,6,12]_enc(1x3)-dec(1x2)-pre(1x3)-post(1x3)/ep160-b600-lr(0.002)_beta(0.7:0x0.5)_lamb(0.0001)_gr(250.0)_(2023_04_29,17:53)',
]
save_script_txt(fits, 'cuda')
# Out:
# [PROGRESS] 'run_gaban.txt' saved at
# /home/hadi/Dropbox/git/_MTMST/scripts

# %% [markdown]
# ## Fixate 1

# %% [markdown]
# ### $\beta = 0.6$

# %%
fit_name = 'fixate1_nf-420_beta-0.6_(2023_04_30,20:36)'
df, df_all, ro_all, args, tr = summarize_neural_fits(fit_name)

_ = show_neural_results(df)
len(df)
# Out:
# 141

# %%
df
# Out:
#     category   nf  beta   root    expt  cell      perf  max_perf  log_alpha  \
# 0    fixate1  420   0.6  YUWEI  clu036     0  0.136964       NaN        5.0
# 1    fixate1  420   0.6  YUWEI  clu037     0  0.288780       NaN        3.0
# 2    fixate1  420   0.6  YUWEI  clu038     0  0.375147       NaN        3.0
# 3    fixate1  420   0.6  YUWEI  clu039     0  0.405588       NaN        3.0
# 4    fixate1  420   0.6  YUWEI  clu040     0  0.534920       NaN       -2.0
# ..       ...  ...   ...    ...     ...   ...       ...       ...        ...
# 136  fixate1  420   0.6  YUWEI  ytu029    19  0.446412  0.941254        4.0
# 137  fixate1  420   0.6  YUWEI  ytu029    20  0.323203  0.958395      -10.0
# 138  fixate1  420   0.6  YUWEI  ytu029    21  0.509688  0.846710        3.0
# 139  fixate1  420   0.6  YUWEI  ytu029    22  0.661793  0.930033        2.0
# 140  fixate1  420   0.6  YUWEI  ytu029    23  0.606277  0.946823        2.0
#
#      best_lag
# 0           3
# 1           3
# 2           1
# 3           0
# 4           3
# ..        ...
# 136         7
# 137         7
# 138         4
# 139         6
# 140         4
#
# [141 rows x 10 columns]

# %% [markdown]
# ### $\beta = 0.7$

# %%
fit_name = 'fixate1_nf-420_beta-0.7_(2023_04_30,21:40)'
df, df_all, ro_all, args, tr = summarize_neural_fits(fit_name)

_ = show_neural_results(df)
len(df)
# Out:
# 141

# %%
df
# Out:
#     category   nf  beta   root    expt  cell      perf  max_perf  log_alpha  \
# 0    fixate1  420   0.7  YUWEI  clu036     0  0.131421       NaN        3.0
# 1    fixate1  420   0.7  YUWEI  clu037     0  0.277746       NaN        3.0
# 2    fixate1  420   0.7  YUWEI  clu038     0  0.361620       NaN        3.0
# 3    fixate1  420   0.7  YUWEI  clu039     0  0.402115       NaN        3.0
# 4    fixate1  420   0.7  YUWEI  clu040     0  0.532881       NaN      -10.0
# ..       ...  ...   ...    ...     ...   ...       ...       ...        ...
# 136  fixate1  420   0.7  YUWEI  ytu029    19  0.447524  0.941254       14.0
# 137  fixate1  420   0.7  YUWEI  ytu029    20  0.251581  0.958395       -6.0
# 138  fixate1  420   0.7  YUWEI  ytu029    21  0.491255  0.846710        1.0
# 139  fixate1  420   0.7  YUWEI  ytu029    22  0.648284  0.930033       -4.0
# 140  fixate1  420   0.7  YUWEI  ytu029    23  0.591515  0.946823       -4.0
#
#      best_lag
# 0           4
# 1           6
# 2           0
# 3           0
# 4           3
# ..        ...
# 136         2
# 137         5
# 138         6
# 139         3
# 140         5
#
# [141 rows x 10 columns]

# %% [markdown]
# ### $\beta = 10$

# %%
fit_name = 'fixate1_nf-420_beta-1e+01_(2023_04_30,22:48)'
df, df_all, ro_all, args, tr = summarize_neural_fits(fit_name)

_ = show_neural_results(df)
len(df)
# Out:
# 141

# %%
df
# Out:
#     category   nf  beta   root    expt  cell      perf  max_perf  log_alpha  \
# 0    fixate1  420  10.0  YUWEI  clu036     0  0.107269       NaN      -10.0
# 1    fixate1  420  10.0  YUWEI  clu037     0  0.236165       NaN      -10.0
# 2    fixate1  420  10.0  YUWEI  clu038     0  0.311113       NaN      -10.0
# 3    fixate1  420  10.0  YUWEI  clu039     0  0.291945       NaN      -10.0
# 4    fixate1  420  10.0  YUWEI  clu040     0  0.400256       NaN      -10.0
# ..       ...  ...   ...    ...     ...   ...       ...       ...        ...
# 136  fixate1  420  10.0  YUWEI  ytu029    19  0.276610  0.941254        1.0
# 137  fixate1  420  10.0  YUWEI  ytu029    20  0.338626  0.958395       -6.0
# 138  fixate1  420  10.0  YUWEI  ytu029    21  0.404134  0.846710       -4.0
# 139  fixate1  420  10.0  YUWEI  ytu029    22  0.413221  0.930033       -2.0
# 140  fixate1  420  10.0  YUWEI  ytu029    23  0.471153  0.946823       -2.0
#
#      best_lag
# 0           4
# 1           9
# 2           0
# 3           2
# 4           3
# ..        ...
# 136         1
# 137         5
# 138         2
# 139         4
# 140        12
#
# [141 rows x 10 columns]
