# %% [markdown]
# # (01) Neural $\beta$ results (KABA)
#
# **Motivation**: Fits on KABA <br>

# %%
# HIDE CODE


import os, sys
from IPython.display import display

# tmp & extras dir
git_dir = os.path.join(os.environ['HOME'], 'Dropbox/git')
extras_dir = os.path.join(git_dir, 'jb-MTMST/_extras')
fig_base_dir = os.path.join(git_dir, 'jb-MTMST/figs')
tmp_dir = os.path.join(git_dir, 'jb-MTMST/tmp')

# GitHub
sys.path.insert(0, os.path.join(git_dir, '_MTMST'))
from vae.train_vae import TrainerVAE, ConfigTrainVAE
from vae.vae2d import VAE, ConfigVAE
from figures.fighelper import *
from analysis.glm import *


# warnings, tqdm, & style
warnings.filterwarnings('ignore', category=DeprecationWarning)
from rich.jupyter import print
# %matplotlib inline
set_style()

# %% [markdown]
# ## Create run script

# %%
fits = [
    'fixate1_k-32_z-20x[3,6,12]_enc(1x3)-dec(1x2)-pre(1x3)-post(1x3)/ep160-b600-lr(0.002)_beta(0.5:0x0.5)_lamb(0.0001)_gr(250.0)_(2023_04_29,17:52)',
    'fixate1_k-32_z-20x[3,6,12]_enc(1x3)-dec(1x2)-pre(1x3)-post(1x3)/ep160-b600-lr(0.002)_beta(0.2:0x0.5)_lamb(0.0001)_gr(250.0)_(2023_04_29,17:52)',
]
save_script_txt(fits, 'cuda:1')
# Out:
# [PROGRESS] 'scripts.txt' saved at
# /home/hadi/Dropbox/git/_MTMST/scripts

# %% [markdown]
# ## Fixate 1

# %% [markdown]
# ### $\beta = 0.5$

# %%
fit_name = 'fixate1_nf-420_beta-0.5_(2023_04_30,20:05)'
df, df_all, ro_all, args, tr = summarize_neural_fits(fit_name)

_ = show_neural_results(df)
len(df)
# Out:
# 141

# %%
df
# Out:
#     category   nf  beta   root    expt  cell      perf  max_perf  log_alpha  \
# 0    fixate1  420   0.5  YUWEI  clu036     0  0.133108       NaN        5.0
# 1    fixate1  420   0.5  YUWEI  clu037     0  0.287652       NaN        3.0
# 2    fixate1  420   0.5  YUWEI  clu038     0  0.377101       NaN        3.0
# 3    fixate1  420   0.5  YUWEI  clu039     0  0.406950       NaN        4.0
# 4    fixate1  420   0.5  YUWEI  clu040     0  0.537178       NaN       -1.0
# ..       ...  ...   ...    ...     ...   ...       ...       ...        ...
# 136  fixate1  420   0.5  YUWEI  ytu029    19  0.434810  0.941254        3.0
# 137  fixate1  420   0.5  YUWEI  ytu029    20  0.377830  0.958395        2.0
# 138  fixate1  420   0.5  YUWEI  ytu029    21  0.502900  0.846710        4.0
# 139  fixate1  420   0.5  YUWEI  ytu029    22  0.577946  0.930033        4.0
# 140  fixate1  420   0.5  YUWEI  ytu029    23  0.685438  0.946823        2.0
#
#      best_lag
# 0           5
# 1           4
# ...

# %% [markdown]
# ### $\beta = 0.2$

# %%
fit_name = 'fixate1_nf-420_beta-0.2_(2023_04_30,21:37)'
df, df_all, ro_all, args, tr = summarize_neural_fits(fit_name)

_ = show_neural_results(df)
len(df)
# Out:
# 141

# %%
df
# Out:
#     category   nf  beta   root    expt  cell      perf  max_perf  log_alpha  \
# 0    fixate1  420   0.2  YUWEI  clu036     0  0.137628       NaN        5.0
# 1    fixate1  420   0.2  YUWEI  clu037     0  0.286208       NaN        3.0
# 2    fixate1  420   0.2  YUWEI  clu038     0  0.375671       NaN        2.0
# 3    fixate1  420   0.2  YUWEI  clu039     0  0.406870       NaN        3.0
# 4    fixate1  420   0.2  YUWEI  clu040     0  0.543278       NaN      -10.0
# ..       ...  ...   ...    ...     ...   ...       ...       ...        ...
# 136  fixate1  420   0.2  YUWEI  ytu029    19  0.366287  0.941254        1.0
# 137  fixate1  420   0.2  YUWEI  ytu029    20  0.330373  0.958395      -10.0
# 138  fixate1  420   0.2  YUWEI  ytu029    21  0.408968  0.846710      -10.0
# 139  fixate1  420   0.2  YUWEI  ytu029    22  0.602342  0.930033        2.0
# 140  fixate1  420   0.2  YUWEI  ytu029    23  0.515337  0.946823        5.0
#
#      best_lag
# 0           4
# 1           3
# ...

# %% [markdown]
# ### $\beta = 0.01$

# %%
fit_name = 'fixate1_nf-420_beta-0.01_(2023_04_30,07:42)'
df, df_all, ro_all, args, tr = summarize_neural_fits(fit_name)

_ = show_neural_results(df)
len(df)
# Out:
# 141

# %%
df
# Out:
#     category   nf  beta   root    expt  cell      perf  max_perf  log_alpha  \
# 0    fixate1  420  0.01  YUWEI  clu036     0  0.137253       NaN        5.0
# 1    fixate1  420  0.01  YUWEI  clu037     0  0.275658       NaN       -6.0
# 2    fixate1  420  0.01  YUWEI  clu038     0  0.369060       NaN        3.0
# 3    fixate1  420  0.01  YUWEI  clu039     0  0.396944       NaN        4.0
# 4    fixate1  420  0.01  YUWEI  clu040     0  0.530941       NaN      -10.0
# ..       ...  ...   ...    ...     ...   ...       ...       ...        ...
# 136  fixate1  420  0.01  YUWEI  ytu029    19  0.348854  0.941254       -8.0
# 137  fixate1  420  0.01  YUWEI  ytu029    20  0.229412  0.958395       -2.0
# 138  fixate1  420  0.01  YUWEI  ytu029    21  0.460649  0.846710       -4.0
# 139  fixate1  420  0.01  YUWEI  ytu029    22  0.661862  0.930033        4.0
# 140  fixate1  420  0.01  YUWEI  ytu029    23  0.525644  0.946823       -2.0
#
#      best_lag
# 0           3
# 1           1
# ...

# %% [markdown]
# ### $\beta = 0.1$

# %%
fit_name = 'fixate1_nf-420_beta-0.1_(2023_04_29,22:01)'
df, df_all, ro_all, args, tr = summarize_neural_fits(fit_name)

_ = show_neural_results(df)
len(df)
# Out:
# 141

# %%
df
# Out:
#     category   nf  beta   root    expt  cell      perf  max_perf  log_alpha  \
# 0    fixate1  420   0.1  YUWEI  clu036     0  0.125960       NaN        4.0
# 1    fixate1  420   0.1  YUWEI  clu037     0  0.262060       NaN        3.0
# 2    fixate1  420   0.1  YUWEI  clu038     0  0.367083       NaN        3.0
# 3    fixate1  420   0.1  YUWEI  clu039     0  0.393411       NaN        2.0
# 4    fixate1  420   0.1  YUWEI  clu040     0  0.523314       NaN       -4.0
# ..       ...  ...   ...    ...     ...   ...       ...       ...        ...
# 136  fixate1  420   0.1  YUWEI  ytu029    19  0.489794  0.941254        4.0
# 137  fixate1  420   0.1  YUWEI  ytu029    20  0.376887  0.958395        1.0
# 138  fixate1  420   0.1  YUWEI  ytu029    21  0.284675  0.846710       -1.0
# 139  fixate1  420   0.1  YUWEI  ytu029    22  0.583849  0.930033       -1.0
# 140  fixate1  420   0.1  YUWEI  ytu029    23  0.414609  0.946823        3.0
#
#      best_lag
# 0           4
# 1           7
# ...

# %% [markdown]
# ### $\beta = 1$

# %%
fit_name = 'fixate1_nf-420_beta-1.0_(2023_04_29,19:41)'
df, df_all, ro_all, args, tr = summarize_neural_fits(fit_name)

_ = show_neural_results(df)
len(df)
# Out:
# 141

# %%
df
# Out:
#     category   nf  beta   root    expt  cell      perf  max_perf  log_alpha  \
# 0    fixate1  420   1.0  YUWEI  clu036     0  0.128572       NaN        1.0
# 1    fixate1  420   1.0  YUWEI  clu037     0  0.277506       NaN      -10.0
# 2    fixate1  420   1.0  YUWEI  clu038     0  0.344392       NaN      -10.0
# 3    fixate1  420   1.0  YUWEI  clu039     0  0.375970       NaN      -10.0
# 4    fixate1  420   1.0  YUWEI  clu040     0  0.521240       NaN      -10.0
# ..       ...  ...   ...    ...     ...   ...       ...       ...        ...
# 136  fixate1  420   1.0  YUWEI  ytu029    19  0.432551  0.941254        0.0
# 137  fixate1  420   1.0  YUWEI  ytu029    20  0.320838  0.958395       -2.0
# 138  fixate1  420   1.0  YUWEI  ytu029    21  0.417884  0.846710       -1.0
# 139  fixate1  420   1.0  YUWEI  ytu029    22  0.635683  0.930033       -1.0
# 140  fixate1  420   1.0  YUWEI  ytu029    23  0.493792  0.946823       -4.0
#
#      best_lag
# 0           3
# 1           3
# ...
