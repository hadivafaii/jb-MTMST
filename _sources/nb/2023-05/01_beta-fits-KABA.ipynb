# %% [markdown]
# # (01) Neural $\beta$ results (KABA)
#
# **Motivation**: Fits on KABA <br>

# %%
# HIDE CODE


import os, sys
from IPython.display import display

# tmp & extras dir
git_dir = os.path.join(os.environ['HOME'], 'Dropbox/git')
extras_dir = os.path.join(git_dir, 'jb-MTMST/_extras')
fig_base_dir = os.path.join(git_dir, 'jb-MTMST/figs')
tmp_dir = os.path.join(git_dir, 'jb-MTMST/tmp')

# GitHub
sys.path.insert(0, os.path.join(git_dir, '_MTMST'))
from vae.train_vae import TrainerVAE, ConfigTrainVAE
from vae.vae2d import VAE, ConfigVAE
from figures.fighelper import *
from analysis.glm import *


# warnings, tqdm, & style
warnings.filterwarnings('ignore', category=DeprecationWarning)
from rich.jupyter import print
# %matplotlib inline
set_style()

# %% [markdown]
# ## Create run script

# %%
fits = [
    'fixate1_k-40_z-420x[1]_enc(0x3)-dec(0x2)-pre(3x13)-post(3x12)/ep160-b600-lr(0.002)_beta(0.001:0x0.5)_lamb(0.0001)_gr(250.0)_(2023_05_14,21:11)',
]
save_script_neural(fits, 'cuda:1')
# Out:
# [PROGRESS] 'run_neuron_kaba.txt' saved at
# /home/hadi/Dropbox/git/_MTMST/scripts

# %% [markdown]
# ## Obj 1

# %% [markdown]
# ### $\beta = 5$

# %%
fit_name = 'obj1_nf-280_beta-5.0_(2023_05_15,07:20)'
df, df_all, ro_all, args, tr = summarize_neural_fits(fit_name)

_ = show_neural_results(df)
len(df)
# Out:
# 141

# %%
inds = df['perf'].argsort()[::-1]
df.iloc[inds]
# Out:
#     category   nf  beta   root    expt  cell      perf  max_perf  log_alpha  \
# 118     obj1  280   5.0  YUWEI  ytu028     8  0.886749  0.328052        6.0
# 124     obj1  280   5.0  YUWEI  ytu029     4  0.864878  0.935583      -10.0
# 42      obj1  280   5.0  YUWEI  clu209     1  0.855282  0.923722        3.0
# 49      obj1  280   5.0  YUWEI  clu221     1  0.800172  0.924544       -8.0
# 51      obj1  280   5.0  YUWEI  clu221     3  0.779763  0.900849       -2.0
# ..       ...  ...   ...    ...     ...   ...       ...       ...        ...
# 103     obj1  280   5.0  YUWEI  clu294    10  0.078988       NaN      -10.0
# 102     obj1  280   5.0  YUWEI  clu294     9  0.067605       NaN        6.0
# 13      obj1  280   5.0  YUWEI  clu069     0  0.041067       NaN      -10.0
# 96      obj1  280   5.0  YUWEI  clu294     2  0.038880       NaN        5.0
# 97      obj1  280   5.0  YUWEI  clu294     3  0.037825       NaN        4.0
#
#      best_lag
# 118         8
# 124         4
# 42          5
# 49          6
# 51          4
# ..        ...
# 103         6
# 102         2
# 13          5
# 96          4
# 97          9
#
# [141 rows x 10 columns]

# %% [markdown]
# ### $\beta = 0.8$

# %%
fit_name = 'obj1_nf-280_beta-0.8_(2023_05_14,22:09)'
df, df_all, ro_all, args, tr = summarize_neural_fits(fit_name)

_ = show_neural_results(df)
len(df)
# Out:
# 141

# %%
inds = df['perf'].argsort()[::-1]
df.iloc[inds]
# Out:
#     category   nf  beta   root    expt  cell      perf  max_perf  log_alpha  \
# 42      obj1  280   0.8  YUWEI  clu209     1  0.878843  0.923722        2.0
# 51      obj1  280   0.8  YUWEI  clu221     3  0.848080  0.900849       -4.0
# 28      obj1  280   0.8  YUWEI  clu116     0  0.822464  0.835483        2.0
# 69      obj1  280   0.8  YUWEI  clu267     4  0.813621  0.979806       -8.0
# 43      obj1  280   0.8  YUWEI  clu209     4  0.799455  0.933615        6.0
# ..       ...  ...   ...    ...     ...   ...       ...       ...        ...
# 96      obj1  280   0.8  YUWEI  clu294     2  0.107667       NaN        6.0
# 97      obj1  280   0.8  YUWEI  clu294     3  0.085427       NaN        6.0
# 13      obj1  280   0.8  YUWEI  clu069     0  0.069271       NaN        6.0
# 102     obj1  280   0.8  YUWEI  clu294     9  0.067093       NaN        1.0
# 31      obj1  280   0.8  YUWEI  clu131     0  0.060687  0.843686        5.0
#
#      best_lag
# 42          4
# 51          5
# 28          3
# 69          5
# 43          3
# ..        ...
# 96          9
# 97          0
# 13          4
# 102         0
# 31          2
#
# [141 rows x 10 columns]

# %% [markdown]
# ### $\beta = 0.1$

# %%
fit_name = 'obj1_nf-280_beta-0.1_(2023_05_14,08:28)'
df, df_all, ro_all, args, tr = summarize_neural_fits(fit_name)

_ = show_neural_results(df)
len(df)
# Out:
# 141

# %%
inds = df['perf'].argsort()[::-1]
df.iloc[inds]
# Out:
#     category   nf  beta   root    expt  cell      perf  max_perf  log_alpha  \
# 124     obj1  280   0.1  YUWEI  ytu029     4  0.877843  0.935583        4.0
# 42      obj1  280   0.1  YUWEI  clu209     1  0.833650  0.923722        5.0
# 67      obj1  280   0.1  YUWEI  clu267     1  0.829790  0.944895        5.0
# 29      obj1  280   0.1  YUWEI  clu120     0  0.820206  0.967720        6.0
# 108     obj1  280   0.1  YUWEI  clu295     3  0.793080  0.949908       -8.0
# ..       ...  ...   ...    ...     ...   ...       ...       ...        ...
# 96      obj1  280   0.1  YUWEI  clu294     2  0.117161       NaN        5.0
# 79      obj1  280   0.1  YUWEI  clu292     2  0.103301  0.805540       -1.0
# 97      obj1  280   0.1  YUWEI  clu294     3  0.087513       NaN        6.0
# 13      obj1  280   0.1  YUWEI  clu069     0  0.078963       NaN        6.0
# 102     obj1  280   0.1  YUWEI  clu294     9  0.062425       NaN        6.0
#
#      best_lag
# 124         4
# 42          3
# 67          9
# 29          3
# 108         2
# ..        ...
# 96          9
# 79          3
# 97          0
# 13          4
# 102         3
#
# [141 rows x 10 columns]

# %% [markdown]
# ### $\beta = 2$

# %%
fit_name = 'obj1_nf-280_beta-2.0_(2023_05_13,20:52)'
df, df_all, ro_all, args, tr = summarize_neural_fits(fit_name)

_ = show_neural_results(df)
len(df)
# Out:
# 141

# %%
inds = df['perf'].argsort()[::-1]
df.iloc[inds]
# Out:
#     category   nf  beta   root    expt  cell      perf  max_perf  log_alpha  \
# 42      obj1  280   2.0  YUWEI  clu209     1  0.848385  0.923722      -10.0
# 43      obj1  280   2.0  YUWEI  clu209     4  0.831708  0.933615      -10.0
# 70      obj1  280   2.0  YUWEI  clu267     5  0.817206  0.984911        2.0
# 125     obj1  280   2.0  YUWEI  ytu029     5  0.800236  0.509045        0.0
# 118     obj1  280   2.0  YUWEI  ytu028     8  0.786227  0.328052        1.0
# ..       ...  ...   ...    ...     ...   ...       ...       ...        ...
# 10      obj1  280   2.0  YUWEI  clu061     0  0.071172       NaN      -10.0
# 102     obj1  280   2.0  YUWEI  clu294     9  0.054517       NaN      -10.0
# 13      obj1  280   2.0  YUWEI  clu069     0  0.047163       NaN      -10.0
# 96      obj1  280   2.0  YUWEI  clu294     2  0.047099       NaN      -10.0
# 97      obj1  280   2.0  YUWEI  clu294     3  0.041285       NaN        5.0
#
#      best_lag
# 42          6
# 43          5
# 70          7
# 125        10
# 118        10
# ..        ...
# 10          4
# 102         2
# 13          8
# 96          2
# 97          6
#
# [141 rows x 10 columns]

# %% [markdown]
# ### $\beta = 10$

# %%
fit_name = 'obj1_nf-280_beta-10.0_(2023_05_12,21:30)'
df, df_all, ro_all, args, tr = summarize_neural_fits(fit_name)

_ = show_neural_results(df)
len(df)
# Out:
# 141

# %%
inds = df['perf'].argsort()[::-1]
df.iloc[inds]
# Out:
#     category   nf  beta   root    expt  cell      perf  max_perf  log_alpha  \
# 118     obj1  280  10.0  YUWEI  ytu028     8  0.943909  0.328052       -1.0
# 70      obj1  280  10.0  YUWEI  clu267     5  0.813832  0.984911        3.0
# 51      obj1  280  10.0  YUWEI  clu221     3  0.809771  0.900849      -10.0
# 42      obj1  280  10.0  YUWEI  clu209     1  0.807098  0.923722       -1.0
# 50      obj1  280  10.0  YUWEI  clu221     2  0.759359  0.921324        1.0
# ..       ...  ...   ...    ...     ...   ...       ...       ...        ...
# 96      obj1  280  10.0  YUWEI  clu294     2  0.071449       NaN      -10.0
# 103     obj1  280  10.0  YUWEI  clu294    10  0.070060       NaN      -10.0
# 97      obj1  280  10.0  YUWEI  clu294     3  0.052315       NaN        6.0
# 13      obj1  280  10.0  YUWEI  clu069     0  0.046726       NaN      -10.0
# 102     obj1  280  10.0  YUWEI  clu294     9  0.033465       NaN      -10.0
#
#      best_lag
# 118         9
# 70          7
# 51          6
# 42          4
# 50          6
# ..        ...
# 96         10
# 103         3
# 97          4
# 13          4
# 102         8
#
# [141 rows x 10 columns]

# %% [markdown]
# ## Fixate 0

# %% [markdown]
# ### $\beta = 0.8$

# %%
fit_name = 'fixate0_nf-280_beta-0.8_(2023_05_14,21:07)'
df, df_all, ro_all, args, tr = summarize_neural_fits(fit_name)

_ = show_neural_results(df)
len(df)
# Out:
# 141

# %%
inds = df['perf'].argsort()[::-1]
df.iloc[inds]
# Out:
#     category   nf  beta   root    expt  cell      perf  max_perf  log_alpha  \
# 28   fixate0  280   0.8  YUWEI  clu116     0  0.877586  0.835483        3.0
# 42   fixate0  280   0.8  YUWEI  clu209     1  0.859692  0.923722        2.0
# 69   fixate0  280   0.8  YUWEI  clu267     4  0.859543  0.979806        0.0
# 124  fixate0  280   0.8  YUWEI  ytu029     4  0.852507  0.935583        5.0
# 70   fixate0  280   0.8  YUWEI  clu267     5  0.840044  0.984911        5.0
# ..       ...  ...   ...    ...     ...   ...       ...       ...        ...
# 13   fixate0  280   0.8  YUWEI  clu069     0  0.070837       NaN        4.0
# 96   fixate0  280   0.8  YUWEI  clu294     2  0.065920       NaN        4.0
# 102  fixate0  280   0.8  YUWEI  clu294     9  0.055508       NaN       14.0
# 66   fixate0  280   0.8  YUWEI  clu229    11  0.038025  0.716168       14.0
# 97   fixate0  280   0.8  YUWEI  clu294     3  0.033924       NaN        4.0
#
#      best_lag
# 28          3
# 42          5
# 69          4
# 124         5
# 70          7
# ..        ...
# 13          4
# 96          7
# 102         7
# 66          7
# 97          6
#
# [141 rows x 10 columns]

# %% [markdown]
# ### $\beta = 0.1$

# %%
fit_name = 'fixate0_nf-280_beta-0.1_(2023_05_11,19:22)'
df, df_all, ro_all, args, tr = summarize_neural_fits(fit_name)

_ = show_neural_results(df)
len(df)
# Out:
# 141

# %%
inds = df['perf'].argsort()[::-1]
df.iloc[inds]
# Out:
#     category   nf  beta   root    expt  cell      perf  max_perf  log_alpha  \
# 28   fixate0  280   0.1  YUWEI  clu116     0  0.860555  0.835483        3.0
# 29   fixate0  280   0.1  YUWEI  clu120     0  0.851417  0.967720        0.0
# 43   fixate0  280   0.1  YUWEI  clu209     4  0.845311  0.933615      -10.0
# 67   fixate0  280   0.1  YUWEI  clu267     1  0.830018  0.944895        0.0
# 42   fixate0  280   0.1  YUWEI  clu209     1  0.825745  0.923722        4.0
# ..       ...  ...   ...    ...     ...   ...       ...       ...        ...
# 103  fixate0  280   0.1  YUWEI  clu294    10  0.101370       NaN      -10.0
# 102  fixate0  280   0.1  YUWEI  clu294     9  0.071366       NaN       -8.0
# 96   fixate0  280   0.1  YUWEI  clu294     2  0.065455       NaN       -1.0
# 13   fixate0  280   0.1  YUWEI  clu069     0  0.062454       NaN      -10.0
# 97   fixate0  280   0.1  YUWEI  clu294     3  0.034574       NaN        4.0
#
#      best_lag
# 28          3
# 29          4
# 43          3
# 67          7
# 42          5
# ..        ...
# 103         2
# 102         4
# 96          7
# 13          5
# 97          8
#
# [141 rows x 10 columns]

# %% [markdown]
# ### $\beta = 0.5$

# %%
fit_name = 'fixate0_nf-280_beta-0.5_(2023_05_11,20:35)'
df, df_all, ro_all, args, tr = summarize_neural_fits(fit_name)

_ = show_neural_results(df)
len(df)
# Out:
# 141

# %%
inds = df['perf'].argsort()[::-1]
df.iloc[inds]
# Out:
#     category   nf  beta   root    expt  cell      perf  max_perf  log_alpha  \
# 28   fixate0  280   0.5  YUWEI  clu116     0  0.878312  0.835483      -10.0
# 69   fixate0  280   0.5  YUWEI  clu267     4  0.854417  0.979806      -10.0
# 42   fixate0  280   0.5  YUWEI  clu209     1  0.834999  0.923722       -2.0
# 51   fixate0  280   0.5  YUWEI  clu221     3  0.818341  0.900849        2.0
# 29   fixate0  280   0.5  YUWEI  clu120     0  0.815376  0.967720        4.0
# ..       ...  ...   ...    ...     ...   ...       ...       ...        ...
# 96   fixate0  280   0.5  YUWEI  clu294     2  0.064808       NaN        3.0
# 66   fixate0  280   0.5  YUWEI  clu229    11  0.060578  0.716168        0.0
# 13   fixate0  280   0.5  YUWEI  clu069     0  0.059586       NaN        1.0
# 102  fixate0  280   0.5  YUWEI  clu294     9  0.056592       NaN        0.0
# 97   fixate0  280   0.5  YUWEI  clu294     3  0.021257       NaN       10.0
#
#      best_lag
# 28          2
# 69          4
# 42          4
# 51          5
# 29          3
# ..        ...
# 96         12
# 66          5
# 13          5
# 102         7
# 97          4
#
# [141 rows x 10 columns]

# %% [markdown]
# ## Fixate 1 (Vanilla)

# %% [markdown]
# ### $\beta = 0.001$

# %%
fit_name = 'vanilla_fixate1_nf-420_beta-0.001_(2023_05_16,08:26)'
df, df_all, ro_all, args, tr = summarize_neural_fits(fit_name)

_ = show_neural_results(df)
len(df)
# Out:
# 141

# %%
inds = df['perf'].argsort()[::-1]
df.iloc[inds]
# Out:
#     category   nf   beta   root    expt  cell      perf  max_perf  log_alpha  \
# 124  fixate1  420  0.001  YUWEI  ytu029     4  0.905721  0.935583        1.0
# 29   fixate1  420  0.001  YUWEI  clu120     0  0.903889  0.967720        0.0
# 42   fixate1  420  0.001  YUWEI  clu209     1  0.903523  0.923722        0.0
# 51   fixate1  420  0.001  YUWEI  clu221     3  0.895365  0.900849        2.0
# 72   fixate1  420  0.001  YUWEI  clu267     7  0.858997  0.955361       -8.0
# ..       ...  ...    ...    ...     ...   ...       ...       ...        ...
# 103  fixate1  420  0.001  YUWEI  clu294    10  0.084607       NaN        0.0
# 13   fixate1  420  0.001  YUWEI  clu069     0  0.078394       NaN        1.0
# 96   fixate1  420  0.001  YUWEI  clu294     2  0.077481       NaN        1.0
# 97   fixate1  420  0.001  YUWEI  clu294     3  0.068141       NaN        4.0
# 102  fixate1  420  0.001  YUWEI  clu294     9  0.056356       NaN        2.0
#
#      best_lag
# 124         4
# 29          4
# 42          4
# 51          5
# 72          5
# ..        ...
# 103         5
# 13          4
# 96          7
# 97          7
# 102         0
#
# [141 rows x 10 columns]

# %% [markdown]
# ### $\beta = 0.01$

# %%
fit_name = 'vanilla_fixate1_nf-420_beta-0.01_(2023_05_13,21:48)'
df, df_all, ro_all, args, tr = summarize_neural_fits(fit_name)

_ = show_neural_results(df)
len(df)
# Out:
# 141

# %%
inds = df['perf'].argsort()[::-1]
df.iloc[inds]
# Out:
#     category   nf  beta   root    expt  cell      perf  max_perf  log_alpha  \
# 51   fixate1  420  0.01  YUWEI  clu221     3  0.914701  0.900849        1.0
# 42   fixate1  420  0.01  YUWEI  clu209     1  0.895307  0.923722        0.0
# 124  fixate1  420  0.01  YUWEI  ytu029     4  0.881948  0.935583       -1.0
# 50   fixate1  420  0.01  YUWEI  clu221     2  0.872197  0.921324        1.0
# 29   fixate1  420  0.01  YUWEI  clu120     0  0.867555  0.967720       -2.0
# ..       ...  ...   ...    ...     ...   ...       ...       ...        ...
# 103  fixate1  420  0.01  YUWEI  clu294    10  0.088224       NaN        0.0
# 96   fixate1  420  0.01  YUWEI  clu294     2  0.087547       NaN        1.0
# 97   fixate1  420  0.01  YUWEI  clu294     3  0.072599       NaN        4.0
# 13   fixate1  420  0.01  YUWEI  clu069     0  0.070046       NaN        0.0
# 102  fixate1  420  0.01  YUWEI  clu294     9  0.058520       NaN        1.0
#
#      best_lag
# 51          4
# 42          3
# 124         3
# 50          3
# 29          4
# ..        ...
# 103         4
# 96          8
# 97          7
# 13          4
# 102         0
#
# [141 rows x 10 columns]

# %% [markdown]
# ### $\beta = 0.7$

# %%
fit_name = 'vanilla_fixate1_nf-420_beta-0.7_(2023_05_12,08:53)'
df, df_all, ro_all, args, tr = summarize_neural_fits(fit_name)

_ = show_neural_results(df)
len(df)
# Out:
# 141

# %%
inds = df['perf'].argsort()[::-1]
df.iloc[inds]
# Out:
#     category   nf  beta   root    expt  cell      perf  max_perf  log_alpha  \
# 42   fixate1  420   0.7  YUWEI  clu209     1  0.872171  0.923722       -4.0
# 43   fixate1  420   0.7  YUWEI  clu209     4  0.842263  0.933615       -2.0
# 109  fixate1  420   0.7  YUWEI  clu295     4  0.821409  0.929612       -4.0
# 19   fixate1  420   0.7  YUWEI  clu090     0  0.820768  0.990020      -10.0
# 111  fixate1  420   0.7  YUWEI  clu295     8  0.819001  0.987233      -10.0
# ..       ...  ...   ...    ...     ...   ...       ...       ...        ...
# 103  fixate1  420   0.7  YUWEI  clu294    10  0.117680       NaN       -4.0
# 96   fixate1  420   0.7  YUWEI  clu294     2  0.108650       NaN       -2.0
# 97   fixate1  420   0.7  YUWEI  clu294     3  0.073784       NaN       -2.0
# 13   fixate1  420   0.7  YUWEI  clu069     0  0.065802       NaN       -2.0
# 102  fixate1  420   0.7  YUWEI  clu294     9  0.056278       NaN       -2.0
#
#      best_lag
# 42          4
# 43          4
# 109         4
# 19          3
# 111         4
# ..        ...
# 103        12
# 96         12
# 97         11
# 13          5
# 102         0
#
# [141 rows x 10 columns]

# %% [markdown]
# ### $\beta = 0.8$

# %%
fit_name = 'vanilla_fixate1_nf-420_beta-0.8_(2023_05_11,02:19)'
df, df_all, ro_all, args, tr = summarize_neural_fits(fit_name)

_ = show_neural_results(df)
len(df)
# Out:
# 141

# %%
inds = df['perf'].argsort()[::-1]
df.iloc[inds]
# Out:
#     category   nf  beta   root    expt  cell      perf  max_perf  log_alpha  \
# 51   fixate1  420   0.8  YUWEI  clu221     3  0.844364  0.900849       -1.0
# 69   fixate1  420   0.8  YUWEI  clu267     4  0.813437  0.979806       -2.0
# 80   fixate1  420   0.8  YUWEI  clu292     4  0.801900  0.982296       -8.0
# 42   fixate1  420   0.8  YUWEI  clu209     1  0.800355  0.923722       -6.0
# 110  fixate1  420   0.8  YUWEI  clu295     5  0.796017  0.856013       -8.0
# ..       ...  ...   ...    ...     ...   ...       ...       ...        ...
# 96   fixate1  420   0.8  YUWEI  clu294     2  0.112620       NaN       -4.0
# 123  fixate1  420   0.8  YUWEI  ytu029     3  0.086381  0.668747        8.0
# 13   fixate1  420   0.8  YUWEI  clu069     0  0.063685       NaN       -4.0
# 97   fixate1  420   0.8  YUWEI  clu294     3  0.062917       NaN       -4.0
# 102  fixate1  420   0.8  YUWEI  clu294     9  0.055805       NaN       -4.0
#
#      best_lag
# 51          4
# 69          5
# 80          4
# 42          3
# 110         2
# ..        ...
# 96          8
# 123         3
# 13          5
# 97          9
# 102         1
#
# [141 rows x 10 columns]

# %% [markdown]
# ### $\beta = 0.2$

# %%
fit_name = 'vanilla_fixate1_nf-420_beta-0.2_(2023_05_10,23:41)'
df, df_all, ro_all, args, tr = summarize_neural_fits(fit_name)

_ = show_neural_results(df)
len(df)
# Out:
# 141

# %%
inds = df['perf'].argsort()[::-1]
df.iloc[inds]
# Out:
#     category   nf  beta   root    expt  cell      perf  max_perf  log_alpha  \
# 124  fixate1  420   0.2  YUWEI  ytu029     4  0.907480  0.935583       -1.0
# 51   fixate1  420   0.2  YUWEI  clu221     3  0.883512  0.900849       -2.0
# 29   fixate1  420   0.2  YUWEI  clu120     0  0.881332  0.967720       -1.0
# 42   fixate1  420   0.2  YUWEI  clu209     1  0.869232  0.923722       -1.0
# 69   fixate1  420   0.2  YUWEI  clu267     4  0.860468  0.979806      -10.0
# ..       ...  ...   ...    ...     ...   ...       ...       ...        ...
# 96   fixate1  420   0.2  YUWEI  clu294     2  0.083465       NaN       -1.0
# 34   fixate1  420   0.2  YUWEI  clu145     0  0.079860  0.593791        3.0
# 13   fixate1  420   0.2  YUWEI  clu069     0  0.071571       NaN        0.0
# 102  fixate1  420   0.2  YUWEI  clu294     9  0.056366       NaN       -1.0
# 130  fixate1  420   0.2  YUWEI  ytu029    12  0.018984  0.324496        0.0
#
#      best_lag
# 124         3
# 51          3
# 29          4
# 42          4
# 69          3
# ..        ...
# 96         12
# 34          0
# 13          4
# 102         2
# 130         0
#
# [141 rows x 10 columns]

# %% [markdown]
# ### $\beta = 0.1$

# %%
fit_name = 'vanilla_fixate1_nf-420_beta-0.1_(2023_05_10,21:14)'
df, df_all, ro_all, args, tr = summarize_neural_fits(fit_name)

_ = show_neural_results(df)
len(df)
# Out:
# 141

# %%
inds = df['perf'].argsort()[::-1]
df.iloc[inds]
# Out:
#     category   nf  beta   root    expt  cell      perf  max_perf  log_alpha  \
# 51   fixate1  420   0.1  YUWEI  clu221     3  0.931666  0.900849       -2.0
# 42   fixate1  420   0.1  YUWEI  clu209     1  0.915104  0.923722       -2.0
# 124  fixate1  420   0.1  YUWEI  ytu029     4  0.902661  0.935583       -1.0
# 49   fixate1  420   0.1  YUWEI  clu221     1  0.880333  0.924544      -10.0
# 69   fixate1  420   0.1  YUWEI  clu267     4  0.867752  0.979806       -6.0
# ..       ...  ...   ...    ...     ...   ...       ...       ...        ...
# 97   fixate1  420   0.1  YUWEI  clu294     3  0.070929       NaN        1.0
# 13   fixate1  420   0.1  YUWEI  clu069     0  0.069028       NaN       -2.0
# 118  fixate1  420   0.1  YUWEI  ytu028     8  0.060838  0.328052        2.0
# 102  fixate1  420   0.1  YUWEI  clu294     9  0.051823       NaN       -2.0
# 34   fixate1  420   0.1  YUWEI  clu145     0 -0.006979  0.593791      -10.0
#
#      best_lag
# 51          4
# 42          3
# 124         3
# 49          3
# 69          4
# ..        ...
# 97          6
# 13          4
# 118         9
# 102         2
# 34          0
#
# [141 rows x 10 columns]

# %% [markdown]
# ## Transl 1

# %% [markdown]
# ### $\beta = 0.01$

# %%
fit_name = 'transl1_nf-420_beta-0.01_(2023_05_04,09:38)'
df, df_all, ro_all, args, tr = summarize_neural_fits(fit_name)

_ = show_neural_results(df)
len(df)
# Out:
# 141

# %%
inds = df['perf'].argsort()[::-1]
df.iloc[inds]
# Out:
#     category   nf  beta   root    expt  cell      perf  max_perf  log_alpha  \
# 124  transl1  420  0.01  YUWEI  ytu029     4  0.870569  0.935583        5.0
# 29   transl1  420  0.01  YUWEI  clu120     0  0.861809  0.967720        5.0
# 28   transl1  420  0.01  YUWEI  clu116     0  0.844607  0.835483        0.0
# 42   transl1  420  0.01  YUWEI  clu209     1  0.832756  0.923722      -10.0
# 19   transl1  420  0.01  YUWEI  clu090     0  0.831846  0.990020       -1.0
# ..       ...  ...   ...    ...     ...   ...       ...       ...        ...
# 103  transl1  420  0.01  YUWEI  clu294    10  0.100839       NaN        5.0
# 34   transl1  420  0.01  YUWEI  clu145     0  0.088876  0.593791      -10.0
# 97   transl1  420  0.01  YUWEI  clu294     3  0.077444       NaN        6.0
# 13   transl1  420  0.01  YUWEI  clu069     0  0.077190       NaN        6.0
# 102  transl1  420  0.01  YUWEI  clu294     9  0.074681       NaN        6.0
#
#      best_lag
# 124         4
# 29          3
# 28          3
# 42          5
# 19          2
# ..        ...
# 103         6
# 34          2
# 97          2
# 13          4
# 102         2
#
# [141 rows x 10 columns]

# %% [markdown]
# ### $\beta = 0.3$

# %%
fit_name = 'transl1_nf-420_beta-0.3_(2023_05_04,11:11)'
df, df_all, ro_all, args, tr = summarize_neural_fits(fit_name)

_ = show_neural_results(df)
len(df)
# Out:
# 141

# %%
inds = df['perf'].argsort()[::-1]
df.iloc[inds]
# Out:
#     category   nf  beta   root    expt  cell      perf  max_perf  log_alpha  \
# 29   transl1  420   0.3  YUWEI  clu120     0  0.900389  0.967720        5.0
# 51   transl1  420   0.3  YUWEI  clu221     3  0.875021  0.900849       -8.0
# 69   transl1  420   0.3  YUWEI  clu267     4  0.864125  0.979806       -4.0
# 124  transl1  420   0.3  YUWEI  ytu029     4  0.860614  0.935583        6.0
# 42   transl1  420   0.3  YUWEI  clu209     1  0.851727  0.923722        3.0
# ..       ...  ...   ...    ...     ...   ...       ...       ...        ...
# 103  transl1  420   0.3  YUWEI  clu294    10  0.122846       NaN        5.0
# 96   transl1  420   0.3  YUWEI  clu294     2  0.120533       NaN        5.0
# 97   transl1  420   0.3  YUWEI  clu294     3  0.093161       NaN        6.0
# 13   transl1  420   0.3  YUWEI  clu069     0  0.072725       NaN        6.0
# 102  transl1  420   0.3  YUWEI  clu294     9  0.061892       NaN        6.0
#
#      best_lag
# 29          3
# 51          4
# 69          4
# 124         3
# 42          3
# ..        ...
# 103        12
# 96          6
# 97          4
# 13          4
# 102         3
#
# [141 rows x 10 columns]

# %% [markdown]
# ### $\beta = 0.8$

# %%
fit_name = 'transl1_nf-420_beta-0.8_(2023_05_04,12:46)'
df, df_all, ro_all, args, tr = summarize_neural_fits(fit_name)

_ = show_neural_results(df)
len(df)
# Out:
# 141

# %%
inds = df['perf'].argsort()[::-1]
df.iloc[inds]
# Out:
#     category   nf  beta   root    expt  cell      perf  max_perf  log_alpha  \
# 51   transl1  420   0.8  YUWEI  clu221     3  0.896835  0.900849      -10.0
# 131  transl1  420   0.8  YUWEI  ytu029    13  0.870102  0.267459        1.0
# 42   transl1  420   0.8  YUWEI  clu209     1  0.868629  0.923722      -10.0
# 50   transl1  420   0.8  YUWEI  clu221     2  0.853909  0.921324        0.0
# 43   transl1  420   0.8  YUWEI  clu209     4  0.841536  0.933615       -2.0
# ..       ...  ...   ...    ...     ...   ...       ...       ...        ...
# 0    transl1  420   0.8  YUWEI  clu036     0  0.112432       NaN      -10.0
# 96   transl1  420   0.8  YUWEI  clu294     2  0.102622       NaN        1.0
# 13   transl1  420   0.8  YUWEI  clu069     0  0.065169       NaN        1.0
# 97   transl1  420   0.8  YUWEI  clu294     3  0.061235       NaN        1.0
# 102  transl1  420   0.8  YUWEI  clu294     9  0.053808       NaN        1.0
#
#      best_lag
# 51          4
# 131         4
# 42          3
# 50          5
# 43          4
# ..        ...
# 0           4
# 96          6
# 13          5
# 97         10
# 102         4
#
# [141 rows x 10 columns]

# %% [markdown]
# ## $\beta = 0.5$

# %% [markdown]
# ### ```Fixate 2```

# %%
fit_name = 'fixate2_nf-420_beta-0.5_(2023_05_03,08:39)'
df, df_all, ro_all, args, tr = summarize_neural_fits(fit_name)

_ = show_neural_results(df)
len(df)
# Out:
# 141

# %%
inds = df['perf'].argsort()[::-1]
df.iloc[inds]
# Out:
#     category   nf  beta   root    expt  cell      perf  max_perf  log_alpha  \
# 42   fixate2  420   0.5  YUWEI  clu209     1  0.873508  0.923722        4.0
# 29   fixate2  420   0.5  YUWEI  clu120     0  0.848654  0.967720        3.0
# 69   fixate2  420   0.5  YUWEI  clu267     4  0.817755  0.979806        0.0
# 72   fixate2  420   0.5  YUWEI  clu267     7  0.796637  0.955361        4.0
# 109  fixate2  420   0.5  YUWEI  clu295     4  0.796116  0.929612       -1.0
# ..       ...  ...   ...    ...     ...   ...       ...       ...        ...
# 130  fixate2  420   0.5  YUWEI  ytu029    12  0.104805  0.324496       12.0
# 97   fixate2  420   0.5  YUWEI  clu294     3  0.094736       NaN        6.0
# 13   fixate2  420   0.5  YUWEI  clu069     0  0.080688       NaN        5.0
# 102  fixate2  420   0.5  YUWEI  clu294     9  0.060637       NaN        6.0
# 63   fixate2  420   0.5  YUWEI  clu227     0  0.046179  0.857890        3.0
#
#      best_lag
# 42          3
# 29          3
# 69          5
# 72          4
# 109         5
# ..        ...
# 130        10
# 97          5
# 13          4
# 102         4
# 63          6
#
# [141 rows x 10 columns]

# %% [markdown]
# ### ```Transl 2```

# %%
fit_name = 'transl2_nf-420_beta-0.5_(2023_05_03,10:12)'
df, df_all, ro_all, args, tr = summarize_neural_fits(fit_name)

_ = show_neural_results(df)
len(df)
# Out:
# 141

# %%
inds = df['perf'].argsort()[::-1]
df.iloc[inds]
# Out:
#     category   nf  beta   root    expt  cell      perf  max_perf  log_alpha  \
# 29   transl2  420   0.5  YUWEI  clu120     0  0.874859  0.967720        4.0
# 124  transl2  420   0.5  YUWEI  ytu029     4  0.856401  0.935583        5.0
# 69   transl2  420   0.5  YUWEI  clu267     4  0.844751  0.979806       -2.0
# 42   transl2  420   0.5  YUWEI  clu209     1  0.833117  0.923722        3.0
# 72   transl2  420   0.5  YUWEI  clu267     7  0.828298  0.955361        4.0
# ..       ...  ...   ...    ...     ...   ...       ...       ...        ...
# 96   transl2  420   0.5  YUWEI  clu294     2  0.112488       NaN        6.0
# 97   transl2  420   0.5  YUWEI  clu294     3  0.082660       NaN        6.0
# 13   transl2  420   0.5  YUWEI  clu069     0  0.078260       NaN        5.0
# 34   transl2  420   0.5  YUWEI  clu145     0  0.075610  0.593791       -6.0
# 102  transl2  420   0.5  YUWEI  clu294     9  0.065215       NaN        8.0
#
#      best_lag
# 29          3
# 124         3
# 69          4
# 42          2
# 72          4
# ..        ...
# 96         12
# 97          4
# 13          4
# 34          9
# 102         4
#
# [141 rows x 10 columns]

# %% [markdown]
# ### ```Terrain 2```

# %%
fit_name = 'terrain2_nf-420_beta-0.5_(2023_05_03,11:50)'
df, df_all, ro_all, args, tr = summarize_neural_fits(fit_name)

_ = show_neural_results(df)
len(df)
# Out:
# 141

# %%
inds = df['perf'].argsort()[::-1]
df.iloc[inds]
# Out:
#      category   nf  beta   root    expt  cell      perf  max_perf  log_alpha  \
# 28   terrain2  420   0.5  YUWEI  clu116     0  0.873225  0.835483       16.0
# 42   terrain2  420   0.5  YUWEI  clu209     1  0.856509  0.923722        3.0
# 69   terrain2  420   0.5  YUWEI  clu267     4  0.844640  0.979806       16.0
# 19   terrain2  420   0.5  YUWEI  clu090     0  0.841065  0.990020      -10.0
# 51   terrain2  420   0.5  YUWEI  clu221     3  0.829467  0.900849       -4.0
# ..        ...  ...   ...    ...     ...   ...       ...       ...        ...
# 0    terrain2  420   0.5  YUWEI  clu036     0  0.126000       NaN        3.0
# 96   terrain2  420   0.5  YUWEI  clu294     2  0.119181       NaN        6.0
# 97   terrain2  420   0.5  YUWEI  clu294     3  0.091932       NaN        8.0
# 13   terrain2  420   0.5  YUWEI  clu069     0  0.074428       NaN        5.0
# 102  terrain2  420   0.5  YUWEI  clu294     9  0.061616       NaN        4.0
#
#      best_lag
# 28          1
# 42          4
# 69         10
# 19          2
# 51          4
# ..        ...
# 0           2
# 96         12
# 97          0
# 13          4
# 102         3
#
# [141 rows x 10 columns]

# %% [markdown]
# ## $\beta=1$

# %% [markdown]
# ### ```Fixate 2```

# %%
fit_name = 'fixate2_nf-420_beta-1.0_(2023_05_01,22:45)'
df, df_all, ro_all, args, tr = summarize_neural_fits(fit_name)

_ = show_neural_results(df)
len(df)
# Out:
# 141

# %%
inds = df['perf'].argsort()[::-1]
df.iloc[inds]
# Out:
#     category   nf  beta   root    expt  cell      perf  max_perf  log_alpha  \
# 51   fixate2  420   1.0  YUWEI  clu221     3  0.915075  0.900849      -10.0
# 42   fixate2  420   1.0  YUWEI  clu209     1  0.912810  0.923722        2.0
# 49   fixate2  420   1.0  YUWEI  clu221     1  0.885682  0.924544      -10.0
# 43   fixate2  420   1.0  YUWEI  clu209     4  0.861220  0.933615        2.0
# 124  fixate2  420   1.0  YUWEI  ytu029     4  0.859205  0.935583      -10.0
# ..       ...  ...   ...    ...     ...   ...       ...       ...        ...
# 96   fixate2  420   1.0  YUWEI  clu294     2  0.099032       NaN        1.0
# 103  fixate2  420   1.0  YUWEI  clu294    10  0.087645       NaN        1.0
# 97   fixate2  420   1.0  YUWEI  clu294     3  0.067124       NaN        1.0
# 13   fixate2  420   1.0  YUWEI  clu069     0  0.063328       NaN        1.0
# 102  fixate2  420   1.0  YUWEI  clu294     9  0.059069       NaN        1.0
#
#      best_lag
# 51          4
# 42          3
# 49          3
# 43          2
# 124         4
# ..        ...
# 96          3
# 103         0
# 97          9
# 13          5
# 102         7
#
# [141 rows x 10 columns]

# %% [markdown]
# ### ```Transl 2```

# %%
fit_name = 'transl2_nf-420_beta-1.0_(2023_05_02,00:19)'
df, df_all, ro_all, args, tr = summarize_neural_fits(fit_name)

_ = show_neural_results(df)
len(df)
# Out:
# 141

# %%
inds = df['perf'].argsort()[::-1]
df.iloc[inds]
# Out:
#     category   nf  beta   root    expt  cell      perf  max_perf  log_alpha  \
# 69   transl2  420   1.0  YUWEI  clu267     4  0.858257  0.979806      -10.0
# 42   transl2  420   1.0  YUWEI  clu209     1  0.816959  0.923722      -10.0
# 124  transl2  420   1.0  YUWEI  ytu029     4  0.810981  0.935583      -10.0
# 131  transl2  420   1.0  YUWEI  ytu029    13  0.804894  0.267459        0.0
# 80   transl2  420   1.0  YUWEI  clu292     4  0.802732  0.982296      -10.0
# ..       ...  ...   ...    ...     ...   ...       ...       ...        ...
# 103  transl2  420   1.0  YUWEI  clu294    10  0.112531       NaN        1.0
# 96   transl2  420   1.0  YUWEI  clu294     2  0.093583       NaN        1.0
# 97   transl2  420   1.0  YUWEI  clu294     3  0.070365       NaN        2.0
# 13   transl2  420   1.0  YUWEI  clu069     0  0.068743       NaN        1.0
# 102  transl2  420   1.0  YUWEI  clu294     9  0.056517       NaN        0.0
#
#      best_lag
# 69          5
# 42          4
# 124         4
# 131        11
# 80          4
# ..        ...
# 103         4
# 96          5
# 97         10
# 13          4
# 102         7
#
# [141 rows x 10 columns]

# %% [markdown]
# ### ```Terrain 2```

# %%
fit_name = 'terrain2_nf-420_beta-1.0_(2023_05_02,01:53)'
df, df_all, ro_all, args, tr = summarize_neural_fits(fit_name)

_ = show_neural_results(df)
len(df)
# Out:
# 141

# %%
inds = df['perf'].argsort()[::-1]
df.iloc[inds]
# Out:
#      category   nf  beta   root    expt  cell      perf  max_perf  log_alpha  \
# 28   terrain2  420   1.0  YUWEI  clu116     0  0.859375  0.835483        3.0
# 42   terrain2  420   1.0  YUWEI  clu209     1  0.845913  0.923722       -4.0
# 75   terrain2  420   1.0  YUWEI  clu267    11  0.822959  0.850368       -2.0
# 124  terrain2  420   1.0  YUWEI  ytu029     4  0.821598  0.935583        4.0
# 43   terrain2  420   1.0  YUWEI  clu209     4  0.815535  0.933615       -6.0
# ..        ...  ...   ...    ...     ...   ...       ...       ...        ...
# 96   terrain2  420   1.0  YUWEI  clu294     2  0.097394       NaN        5.0
# 103  terrain2  420   1.0  YUWEI  clu294    10  0.087836       NaN        5.0
# 97   terrain2  420   1.0  YUWEI  clu294     3  0.066688       NaN        8.0
# 13   terrain2  420   1.0  YUWEI  clu069     0  0.063910       NaN        3.0
# 102  terrain2  420   1.0  YUWEI  clu294     9  0.057528       NaN        4.0
#
#      best_lag
# 28          2
# 42          3
# 75          1
# 124         2
# 43          2
# ..        ...
# 96          6
# 103        10
# 97          1
# 13          4
# 102         3
#
# [141 rows x 10 columns]

# %% [markdown]
# ## Fixate 1

# %% [markdown]
# ### $\beta = 0.001$

# %%
fit_name = 'fixate1_nf-420_beta-0.001_(2023_05_16,00:03)'
df, df_all, ro_all, args, tr = summarize_neural_fits(fit_name)

_ = show_neural_results(df)
len(df)
# Out:
# 141

# %%
inds = df['perf'].argsort()[::-1]
df.iloc[inds]
# Out:
#     category   nf   beta   root    expt  cell      perf  max_perf  log_alpha  \
# 42   fixate1  420  0.001  YUWEI  clu209     1  0.891427  0.923722        5.0
# 124  fixate1  420  0.001  YUWEI  ytu029     4  0.883172  0.935583        1.0
# 69   fixate1  420  0.001  YUWEI  clu267     4  0.853251  0.979806      -10.0
# 51   fixate1  420  0.001  YUWEI  clu221     3  0.841139  0.900849        5.0
# 29   fixate1  420  0.001  YUWEI  clu120     0  0.837645  0.967720        5.0
# ..       ...  ...    ...    ...     ...   ...       ...       ...        ...
# 68   fixate1  420  0.001  YUWEI  clu267     3  0.121269  0.943782        8.0
# 103  fixate1  420  0.001  YUWEI  clu294    10  0.107167       NaN        5.0
# 97   fixate1  420  0.001  YUWEI  clu294     3  0.094600       NaN        8.0
# 13   fixate1  420  0.001  YUWEI  clu069     0  0.066892       NaN        6.0
# 102  fixate1  420  0.001  YUWEI  clu294     9  0.065538       NaN        4.0
#
#      best_lag
# 42          4
# 124         3
# 69          4
# 51          4
# 29          3
# ..        ...
# 68         10
# 103        10
# 97          3
# 13          4
# 102         2
#
# [141 rows x 10 columns]

# %% [markdown]
# ### $\beta = ae$ (vanilla)

# %%
fit_name = 'vanilla_fixate1_nf-420_beta-ae_(2023_05_13,07:49)'
df, df_all, ro_all, args, tr = summarize_neural_fits(fit_name)

_ = show_neural_results(df)
len(df)
# Out:
# 141

# %%
inds = df['perf'].argsort()[::-1]
df.iloc[inds]
# Out:
#     category   nf beta   root    expt  cell      perf  max_perf  log_alpha  \
# 29   fixate1  420   ae  YUWEI  clu120     0  0.891671  0.967720       -8.0
# 42   fixate1  420   ae  YUWEI  clu209     1  0.888478  0.923722        0.0
# 51   fixate1  420   ae  YUWEI  clu221     3  0.888351  0.900849       -4.0
# 69   fixate1  420   ae  YUWEI  clu267     4  0.865463  0.979806       -2.0
# 124  fixate1  420   ae  YUWEI  ytu029     4  0.864652  0.935583        1.0
# ..       ...  ...  ...    ...     ...   ...       ...       ...        ...
# 103  fixate1  420   ae  YUWEI  clu294    10  0.105954       NaN       -2.0
# 96   fixate1  420   ae  YUWEI  clu294     2  0.078448       NaN       -2.0
# 13   fixate1  420   ae  YUWEI  clu069     0  0.064321       NaN       -2.0
# 102  fixate1  420   ae  YUWEI  clu294     9  0.055686       NaN        1.0
# 97   fixate1  420   ae  YUWEI  clu294     3  0.044199       NaN        8.0
#
#      best_lag
# 29          3
# 42          4
# 51          5
# 69          5
# 124         5
# ..        ...
# 103         5
# 96          8
# 13          4
# 102         7
# 97          3
#
# [141 rows x 10 columns]

# %% [markdown]
# ### $\beta = ae$

# %%
fit_name = 'fixate1_nf-420_beta-ae_(2023_05_12,07:31)'
df, df_all, ro_all, args, tr = summarize_neural_fits(fit_name)

_ = show_neural_results(df)
len(df)
# Out:
# 141

# %%
inds = df['perf'].argsort()[::-1]
df.iloc[inds]
# Out:
#     category   nf beta   root    expt  cell      perf  max_perf  log_alpha  \
# 42   fixate1  420   ae  YUWEI  clu209     1  0.904564  0.923722        5.0
# 69   fixate1  420   ae  YUWEI  clu267     4  0.891663  0.979806        6.0
# 28   fixate1  420   ae  YUWEI  clu116     0  0.856238  0.835483        5.0
# 124  fixate1  420   ae  YUWEI  ytu029     4  0.842486  0.935583        6.0
# 51   fixate1  420   ae  YUWEI  clu221     3  0.836732  0.900849        0.0
# ..       ...  ...  ...    ...     ...   ...       ...       ...        ...
# 13   fixate1  420   ae  YUWEI  clu069     0  0.077299       NaN        4.0
# 31   fixate1  420   ae  YUWEI  clu131     0  0.077085  0.843686        2.0
# 102  fixate1  420   ae  YUWEI  clu294     9  0.068161       NaN        8.0
# 66   fixate1  420   ae  YUWEI  clu229    11  0.052794  0.716168        6.0
# 84   fixate1  420   ae  YUWEI  clu292    13  0.022098  0.871889        5.0
#
#      best_lag
# 42          4
# 69          4
# 28          3
# 124         4
# 51          5
# ..        ...
# 13          4
# 31          9
# 102         5
# 66         12
# 84          2
#
# [141 rows x 10 columns]

# %% [markdown]
# ### $\beta = 20$

# %%
fit_name = 'fixate1_nf-420_beta-20.0_(2023_05_08,16:16)'
df, df_all, ro_all, args, tr = summarize_neural_fits(fit_name)

_ = show_neural_results(df)
len(df)
# Out:
# 141

# %%
inds = df['perf'].argsort()[::-1]
df.iloc[inds]
# Out:
#     category   nf  beta   root    expt  cell      perf  max_perf  log_alpha  \
# 131  fixate1  420  20.0  YUWEI  ytu029    13  0.728331  0.267459       -2.0
# 124  fixate1  420  20.0  YUWEI  ytu029     4  0.724649  0.935583       -4.0
# 70   fixate1  420  20.0  YUWEI  clu267     5  0.714004  0.984911       -4.0
# 119  fixate1  420  20.0  YUWEI  ytu028    18  0.674954  0.759893       -8.0
# 122  fixate1  420  20.0  YUWEI  ytu029     2  0.647596  0.661278       -2.0
# ..       ...  ...   ...    ...     ...   ...       ...       ...        ...
# 23   fixate1  420  20.0  YUWEI  clu104     0  0.030089  0.980831      -10.0
# 0    fixate1  420  20.0  YUWEI  clu036     0  0.024821       NaN        1.0
# 10   fixate1  420  20.0  YUWEI  clu061     0  0.019874       NaN       -4.0
# 13   fixate1  420  20.0  YUWEI  clu069     0  0.019056       NaN        5.0
# 36   fixate1  420  20.0  YUWEI  clu147     0  0.011830       NaN        3.0
#
#      best_lag
# 131         7
# 124         4
# 70          4
# 119         9
# 122        11
# ..        ...
# 23         11
# 0          12
# 10          9
# 13         11
# 36         12
#
# [141 rows x 10 columns]

# %% [markdown]
# ### $\beta = 1.5$

# %%
fit_name = 'fixate1_nf-420_beta-1.5_(2023_05_08,14:55)'
df, df_all, ro_all, args, tr = summarize_neural_fits(fit_name)

_ = show_neural_results(df)
len(df)
# Out:
# 141

# %%
inds = df['perf'].argsort()[::-1]
df.iloc[inds]
# Out:
#     category   nf  beta   root    expt  cell      perf  max_perf  log_alpha  \
# 51   fixate1  420   1.5  YUWEI  clu221     3  0.893852  0.900849      -10.0
# 42   fixate1  420   1.5  YUWEI  clu209     1  0.882089  0.923722      -10.0
# 109  fixate1  420   1.5  YUWEI  clu295     4  0.851695  0.929612      -10.0
# 131  fixate1  420   1.5  YUWEI  ytu029    13  0.828350  0.267459       -4.0
# 33   fixate1  420   1.5  YUWEI  clu142     0  0.828056  0.990764      -10.0
# ..       ...  ...   ...    ...     ...   ...       ...       ...        ...
# 103  fixate1  420   1.5  YUWEI  clu294    10  0.103461       NaN        0.0
# 96   fixate1  420   1.5  YUWEI  clu294     2  0.098740       NaN        1.0
# 97   fixate1  420   1.5  YUWEI  clu294     3  0.070170       NaN        2.0
# 13   fixate1  420   1.5  YUWEI  clu069     0  0.059991       NaN      -10.0
# 102  fixate1  420   1.5  YUWEI  clu294     9  0.057273       NaN      -10.0
#
#      best_lag
# 51          4
# 42          3
# 109         5
# 131         7
# 33          3
# ..        ...
# 103         3
# 96          9
# 97          9
# 13          4
# 102         6
#
# [141 rows x 10 columns]

# %% [markdown]
# ### $\beta = 0.3$

# %%
fit_name = 'fixate1_nf-420_beta-0.3_(2023_05_07,01:03)'
df, df_all, ro_all, args, tr = summarize_neural_fits(fit_name)

_ = show_neural_results(df)
len(df)
# Out:
# 141

# %%
inds = df['perf'].argsort()[::-1]
df.iloc[inds]
# Out:
#     category   nf  beta   root    expt  cell      perf  max_perf  log_alpha  \
# 29   fixate1  420   0.3  YUWEI  clu120     0  0.892561  0.967720        5.0
# 69   fixate1  420   0.3  YUWEI  clu267     4  0.873363  0.979806        3.0
# 124  fixate1  420   0.3  YUWEI  ytu029     4  0.865540  0.935583        2.0
# 42   fixate1  420   0.3  YUWEI  clu209     1  0.862186  0.923722        1.0
# 23   fixate1  420   0.3  YUWEI  clu104     0  0.839311  0.980831        6.0
# ..       ...  ...   ...    ...     ...   ...       ...       ...        ...
# 97   fixate1  420   0.3  YUWEI  clu294     3  0.087140       NaN        8.0
# 68   fixate1  420   0.3  YUWEI  clu267     3  0.083384  0.943782        4.0
# 13   fixate1  420   0.3  YUWEI  clu069     0  0.077746       NaN        5.0
# 102  fixate1  420   0.3  YUWEI  clu294     9  0.066589       NaN        8.0
# 34   fixate1  420   0.3  YUWEI  clu145     0 -0.014680  0.593791       -8.0
#
#      best_lag
# 29          3
# 69          5
# 124         3
# 42          4
# 23          4
# ..        ...
# 97          1
# 68          3
# 13          4
# 102         3
# 34          0
#
# [141 rows x 10 columns]

# %% [markdown]
# ### $\beta = 0.4$

# %%
fit_name = 'fixate1_nf-420_beta-0.4_(2023_05_07,02:37)'
df, df_all, ro_all, args, tr = summarize_neural_fits(fit_name)

_ = show_neural_results(df)
len(df)
# Out:
# 141

# %%
inds = df['perf'].argsort()[::-1]
df.iloc[inds]
# Out:
#     category   nf  beta   root    expt  cell      perf  max_perf  log_alpha  \
# 51   fixate1  420   0.4  YUWEI  clu221     3  0.883898  0.900849        6.0
# 124  fixate1  420   0.4  YUWEI  ytu029     4  0.882556  0.935583        4.0
# 69   fixate1  420   0.4  YUWEI  clu267     4  0.866389  0.979806       -2.0
# 42   fixate1  420   0.4  YUWEI  clu209     1  0.849384  0.923722        3.0
# 28   fixate1  420   0.4  YUWEI  clu116     0  0.841447  0.835483       -2.0
# ..       ...  ...   ...    ...     ...   ...       ...       ...        ...
# 66   fixate1  420   0.4  YUWEI  clu229    11  0.100872  0.716168        6.0
# 97   fixate1  420   0.4  YUWEI  clu294     3  0.086312       NaN        6.0
# 13   fixate1  420   0.4  YUWEI  clu069     0  0.076995       NaN        6.0
# 102  fixate1  420   0.4  YUWEI  clu294     9  0.061028       NaN        4.0
# 34   fixate1  420   0.4  YUWEI  clu145     0  0.041845  0.593791       -6.0
#
#      best_lag
# 51          4
# 124         3
# 69          4
# 42          3
# 28          3
# ..        ...
# 66         11
# 97          1
# 13          4
# 102         3
# 34         11
#
# [141 rows x 10 columns]

# %% [markdown]
# ### $\beta = 0.8 \,\, (checkpoint=140)$

# %%
fit_name = 'fixate1_nf-420_beta-0.8_(2023_05_13,14:52)'
df, df_all, ro_all, args, tr = summarize_neural_fits(fit_name)

_ = show_neural_results(df)
len(df)
# Out:
# 141

# %%
inds = df['perf'].argsort()[::-1]
df.iloc[inds]
# Out:
#     category   nf  beta   root    expt  cell      perf  max_perf  log_alpha  \
# 51   fixate1  420   0.8  YUWEI  clu221     3  0.906447  0.900849        1.0
# 124  fixate1  420   0.8  YUWEI  ytu029     4  0.874565  0.935583      -10.0
# 69   fixate1  420   0.8  YUWEI  clu267     4  0.866520  0.979806      -10.0
# 42   fixate1  420   0.8  YUWEI  clu209     1  0.848482  0.923722        1.0
# 43   fixate1  420   0.8  YUWEI  clu209     4  0.844823  0.933615        1.0
# ..       ...  ...   ...    ...     ...   ...       ...       ...        ...
# 38   fixate1  420   0.8  YUWEI  clu180     0  0.109951       NaN        1.0
# 103  fixate1  420   0.8  YUWEI  clu294    10  0.107781       NaN      -10.0
# 97   fixate1  420   0.8  YUWEI  clu294     3  0.076391       NaN        2.0
# 13   fixate1  420   0.8  YUWEI  clu069     0  0.068218       NaN        1.0
# 102  fixate1  420   0.8  YUWEI  clu294     9  0.051053       NaN        1.0
#
#      best_lag
# 51          4
# 124         4
# 69          5
# 42          3
# 43          1
# ..        ...
# 38         11
# 103         3
# 97         10
# 13          4
# 102         1
#
# [141 rows x 10 columns]

# %% [markdown]
# ### $\beta = 0.8$

# %%
fit_name = 'fixate1_nf-420_beta-0.8_(2023_05_07,04:15)'
df, df_all, ro_all, args, tr = summarize_neural_fits(fit_name)

_ = show_neural_results(df)
len(df)
# Out:
# 141

# %%
inds = df['perf'].argsort()[::-1]
df.iloc[inds]
# Out:
#     category   nf  beta   root    expt  cell      perf  max_perf  log_alpha  \
# 42   fixate1  420   0.8  YUWEI  clu209     1  0.855710  0.923722      -10.0
# 43   fixate1  420   0.8  YUWEI  clu209     4  0.843127  0.933615        2.0
# 109  fixate1  420   0.8  YUWEI  clu295     4  0.838603  0.929612      -10.0
# 69   fixate1  420   0.8  YUWEI  clu267     4  0.831221  0.979806      -10.0
# 49   fixate1  420   0.8  YUWEI  clu221     1  0.816557  0.924544      -10.0
# ..       ...  ...   ...    ...     ...   ...       ...       ...        ...
# 38   fixate1  420   0.8  YUWEI  clu180     0  0.096914       NaN      -10.0
# 103  fixate1  420   0.8  YUWEI  clu294    10  0.082926       NaN      -10.0
# 97   fixate1  420   0.8  YUWEI  clu294     3  0.075266       NaN        2.0
# 13   fixate1  420   0.8  YUWEI  clu069     0  0.061511       NaN      -10.0
# 102  fixate1  420   0.8  YUWEI  clu294     9  0.042787       NaN        2.0
#
#      best_lag
# 42          4
# 43          3
# 109         4
# 69          4
# 49          5
# ..        ...
# 38          0
# 103         7
# 97          0
# 13          4
# 102         1
#
# [141 rows x 10 columns]

# %% [markdown]
# ### $\beta = 0.9$

# %%
fit_name = 'fixate1_nf-420_beta-0.9_(2023_05_07,05:51)'
df, df_all, ro_all, args, tr = summarize_neural_fits(fit_name)

_ = show_neural_results(df)
len(df)
# Out:
# 141

# %%
inds = df['perf'].argsort()[::-1]
df.iloc[inds]
# Out:
#     category   nf  beta   root    expt  cell      perf  max_perf  log_alpha  \
# 42   fixate1  420   0.9  YUWEI  clu209     1  0.847690  0.923722        2.0
# 69   fixate1  420   0.9  YUWEI  clu267     4  0.835634  0.979806       -6.0
# 51   fixate1  420   0.9  YUWEI  clu221     3  0.833710  0.900849      -10.0
# 111  fixate1  420   0.9  YUWEI  clu295     8  0.830026  0.987233      -10.0
# 41   fixate1  420   0.9  YUWEI  clu209     0  0.829403  0.896802      -10.0
# ..       ...  ...   ...    ...     ...   ...       ...       ...        ...
# 103  fixate1  420   0.9  YUWEI  clu294    10  0.097375       NaN        1.0
# 96   fixate1  420   0.9  YUWEI  clu294     2  0.094407       NaN        1.0
# 97   fixate1  420   0.9  YUWEI  clu294     3  0.063642       NaN        1.0
# 13   fixate1  420   0.9  YUWEI  clu069     0  0.060081       NaN      -10.0
# 102  fixate1  420   0.9  YUWEI  clu294     9  0.053399       NaN        1.0
#
#      best_lag
# 42          2
# 69          5
# 51          6
# 111         3
# 41          5
# ..        ...
# 103         4
# 96         11
# 97         12
# 13          5
# 102         6
#
# [141 rows x 10 columns]

# %% [markdown]
# ### $\beta = 2$

# %%
fit_name = 'fixate1_nf-420_beta-2.0_(2023_05_07,07:27)'
df, df_all, ro_all, args, tr = summarize_neural_fits(fit_name)

_ = show_neural_results(df)
len(df)
# Out:
# 141

# %%
inds = df['perf'].argsort()[::-1]
df.iloc[inds]
# Out:
#     category   nf  beta   root    expt  cell      perf  max_perf  log_alpha  \
# 51   fixate1  420   2.0  YUWEI  clu221     3  0.874284  0.900849      -10.0
# 118  fixate1  420   2.0  YUWEI  ytu028     8  0.859389  0.328052       -8.0
# 42   fixate1  420   2.0  YUWEI  clu209     1  0.811595  0.923722      -10.0
# 69   fixate1  420   2.0  YUWEI  clu267     4  0.798709  0.979806      -10.0
# 111  fixate1  420   2.0  YUWEI  clu295     8  0.796283  0.987233      -10.0
# ..       ...  ...   ...    ...     ...   ...       ...       ...        ...
# 38   fixate1  420   2.0  YUWEI  clu180     0  0.103299       NaN        1.0
# 96   fixate1  420   2.0  YUWEI  clu294     2  0.099219       NaN        1.0
# 97   fixate1  420   2.0  YUWEI  clu294     3  0.067016       NaN        1.0
# 13   fixate1  420   2.0  YUWEI  clu069     0  0.061557       NaN        1.0
# 102  fixate1  420   2.0  YUWEI  clu294     9  0.040559       NaN        2.0
#
#      best_lag
# 51          4
# 118         8
# 42          4
# 69          3
# 111         4
# ..        ...
# 38         12
# 96          7
# 97         11
# 13          4
# 102         7
#
# [141 rows x 10 columns]

# %% [markdown]
# ### $\beta = 5$

# %%
fit_name = 'fixate1_nf-420_beta-5.0_(2023_05_07,08:59)'
df, df_all, ro_all, args, tr = summarize_neural_fits(fit_name)

_ = show_neural_results(df)
len(df)
# Out:
# 141

# %%
inds = df['perf'].argsort()[::-1]
df.iloc[inds]
# Out:
#     category   nf  beta   root    expt  cell      perf  max_perf  log_alpha  \
# 109  fixate1  420   5.0  YUWEI  clu295     4  0.851359  0.929612      -10.0
# 42   fixate1  420   5.0  YUWEI  clu209     1  0.838400  0.923722      -10.0
# 111  fixate1  420   5.0  YUWEI  clu295     8  0.815131  0.987233      -10.0
# 19   fixate1  420   5.0  YUWEI  clu090     0  0.809841  0.990020      -10.0
# 51   fixate1  420   5.0  YUWEI  clu221     3  0.772792  0.900849      -10.0
# ..       ...  ...   ...    ...     ...   ...       ...       ...        ...
# 103  fixate1  420   5.0  YUWEI  clu294    10  0.081623       NaN      -10.0
# 96   fixate1  420   5.0  YUWEI  clu294     2  0.076969       NaN        1.0
# 97   fixate1  420   5.0  YUWEI  clu294     3  0.063936       NaN        1.0
# 102  fixate1  420   5.0  YUWEI  clu294     9  0.061938       NaN      -10.0
# 13   fixate1  420   5.0  YUWEI  clu069     0  0.053278       NaN      -10.0
#
#      best_lag
# 109         5
# 42          3
# 111         4
# 19          2
# 51          4
# ..        ...
# 103        12
# 96          8
# 97          4
# 102        12
# 13          5
#
# [141 rows x 10 columns]

# %% [markdown]
# ### $\beta = 0.5$

# %%
fit_name = 'fixate1_nf-420_beta-0.5_(2023_04_30,20:05)'
df, df_all, ro_all, args, tr = summarize_neural_fits(fit_name)

_ = show_neural_results(df)
len(df)
# Out:
# 141

# %%
inds = df['perf'].argsort()[::-1]
df.iloc[inds]
# Out:
#     category   nf  beta   root    expt  cell      perf  max_perf  log_alpha  \
# 42   fixate1  420   0.5  YUWEI  clu209     1  0.903883  0.923722      -10.0
# 29   fixate1  420   0.5  YUWEI  clu120     0  0.896783  0.967720        5.0
# 124  fixate1  420   0.5  YUWEI  ytu029     4  0.891866  0.935583        6.0
# 69   fixate1  420   0.5  YUWEI  clu267     4  0.874280  0.979806       -2.0
# 19   fixate1  420   0.5  YUWEI  clu090     0  0.840114  0.990020        2.0
# ..       ...  ...   ...    ...     ...   ...       ...       ...        ...
# 103  fixate1  420   0.5  YUWEI  clu294    10  0.127665       NaN        5.0
# 96   fixate1  420   0.5  YUWEI  clu294     2  0.122705       NaN        6.0
# 97   fixate1  420   0.5  YUWEI  clu294     3  0.094924       NaN        6.0
# 13   fixate1  420   0.5  YUWEI  clu069     0  0.078117       NaN        5.0
# 102  fixate1  420   0.5  YUWEI  clu294     9  0.062244       NaN        6.0
#
#      best_lag
# 42          3
# 29          3
# 124         4
# 69          4
# 19          2
# ..        ...
# 103         9
# 96          6
# 97          4
# 13          4
# 102         3
#
# [141 rows x 10 columns]

# %% [markdown]
# ### $\beta = 0.2$

# %%
fit_name = 'fixate1_nf-420_beta-0.2_(2023_04_30,21:37)'
df, df_all, ro_all, args, tr = summarize_neural_fits(fit_name)

_ = show_neural_results(df)
len(df)
# Out:
# 141

# %%
inds = df['perf'].argsort()[::-1]
df.iloc[inds]
# Out:
#     category   nf  beta   root    expt  cell      perf  max_perf  log_alpha  \
# 124  fixate1  420   0.2  YUWEI  ytu029     4  0.919395  0.935583        5.0
# 42   fixate1  420   0.2  YUWEI  clu209     1  0.897548  0.923722        3.0
# 23   fixate1  420   0.2  YUWEI  clu104     0  0.883021  0.980831        6.0
# 29   fixate1  420   0.2  YUWEI  clu120     0  0.865873  0.967720        5.0
# 69   fixate1  420   0.2  YUWEI  clu267     4  0.862382  0.979806        4.0
# ..       ...  ...   ...    ...     ...   ...       ...       ...        ...
# 13   fixate1  420   0.2  YUWEI  clu069     0  0.083468       NaN        5.0
# 68   fixate1  420   0.2  YUWEI  clu267     3  0.071684  0.943782        5.0
# 102  fixate1  420   0.2  YUWEI  clu294     9  0.059953       NaN        6.0
# 130  fixate1  420   0.2  YUWEI  ytu029    12  0.030094  0.324496        5.0
# 34   fixate1  420   0.2  YUWEI  clu145     0 -0.002190  0.593791        8.0
#
#      best_lag
# 124         3
# 42          3
# 23          4
# 29          3
# 69          5
# ..        ...
# 13          4
# 68          8
# 102         3
# 130         0
# 34          0
#
# [141 rows x 10 columns]

# %% [markdown]
# ### $\beta = 0.01$

# %%
fit_name = 'fixate1_nf-420_beta-0.01_(2023_04_30,07:42)'
df, df_all, ro_all, args, tr = summarize_neural_fits(fit_name)

_ = show_neural_results(df)
len(df)
# Out:
# 141

# %%
inds = df['perf'].argsort()[::-1]
df.iloc[inds]
# Out:
#     category   nf  beta   root    expt  cell      perf  max_perf  log_alpha  \
# 42   fixate1  420  0.01  YUWEI  clu209     1  0.906522  0.923722        0.0
# 124  fixate1  420  0.01  YUWEI  ytu029     4  0.895250  0.935583        5.0
# 23   fixate1  420  0.01  YUWEI  clu104     0  0.866951  0.980831        5.0
# 51   fixate1  420  0.01  YUWEI  clu221     3  0.862644  0.900849        5.0
# 67   fixate1  420  0.01  YUWEI  clu267     1  0.855885  0.944895       -1.0
# ..       ...  ...   ...    ...     ...   ...       ...       ...        ...
# 13   fixate1  420  0.01  YUWEI  clu069     0  0.076943       NaN        6.0
# 102  fixate1  420  0.01  YUWEI  clu294     9  0.070831       NaN        6.0
# 68   fixate1  420  0.01  YUWEI  clu267     3  0.069158  0.943782        2.0
# 83   fixate1  420  0.01  YUWEI  clu292    12  0.054141  0.770807       12.0
# 84   fixate1  420  0.01  YUWEI  clu292    13 -0.077970  0.871889       -4.0
#
#      best_lag
# 42          3
# 124         3
# 23          4
# 51          5
# 67          7
# ..        ...
# 13          4
# 102         3
# 68          5
# 83          0
# 84          5
#
# [141 rows x 10 columns]

# %% [markdown]
# ### $\beta = 0.1$

# %%
fit_name = 'fixate1_nf-420_beta-0.1_(2023_04_29,22:01)'
df, df_all, ro_all, args, tr = summarize_neural_fits(fit_name)

_ = show_neural_results(df)
len(df)
# Out:
# 141

# %%
inds = df['perf'].argsort()[::-1]
df.iloc[inds]
# Out:
#     category   nf  beta   root    expt  cell      perf  max_perf  log_alpha  \
# 124  fixate1  420   0.1  YUWEI  ytu029     4  0.882244  0.935583        4.0
# 23   fixate1  420   0.1  YUWEI  clu104     0  0.858433  0.980831        5.0
# 28   fixate1  420   0.1  YUWEI  clu116     0  0.855118  0.835483        2.0
# 51   fixate1  420   0.1  YUWEI  clu221     3  0.833082  0.900849        5.0
# 29   fixate1  420   0.1  YUWEI  clu120     0  0.824064  0.967720       -6.0
# ..       ...  ...   ...    ...     ...   ...       ...       ...        ...
# 13   fixate1  420   0.1  YUWEI  clu069     0  0.077190       NaN        4.0
# 31   fixate1  420   0.1  YUWEI  clu131     0  0.074209  0.843686       14.0
# 102  fixate1  420   0.1  YUWEI  clu294     9  0.071054       NaN        6.0
# 97   fixate1  420   0.1  YUWEI  clu294     3  0.067741       NaN        6.0
# 66   fixate1  420   0.1  YUWEI  clu229    11  0.061801  0.716168        3.0
#
#      best_lag
# 124         3
# 23          4
# 28          3
# 51          4
# 29          3
# ..        ...
# 13          4
# 31         12
# 102         3
# 97          1
# 66          6
#
# [141 rows x 10 columns]

# %% [markdown]
# ### $\beta = 1$

# %%
fit_name = 'fixate1_nf-420_beta-1.0_(2023_04_29,19:41)'
df, df_all, ro_all, args, tr = summarize_neural_fits(fit_name)

_ = show_neural_results(df)
len(df)
# Out:
# 141

# %%
inds = df['perf'].argsort()[::-1]
df.iloc[inds]
# Out:
#     category   nf  beta   root    expt  cell      perf  max_perf  log_alpha  \
# 42   fixate1  420   1.0  YUWEI  clu209     1  0.874545  0.923722        0.0
# 124  fixate1  420   1.0  YUWEI  ytu029     4  0.845404  0.935583        1.0
# 29   fixate1  420   1.0  YUWEI  clu120     0  0.837122  0.967720      -10.0
# 73   fixate1  420   1.0  YUWEI  clu267     8  0.814474  0.975974      -10.0
# 58   fixate1  420   1.0  YUWEI  clu223    11  0.807218  0.713183        1.0
# ..       ...  ...   ...    ...     ...   ...       ...       ...        ...
# 103  fixate1  420   1.0  YUWEI  clu294    10  0.097727       NaN        1.0
# 96   fixate1  420   1.0  YUWEI  clu294     2  0.087819       NaN        2.0
# 13   fixate1  420   1.0  YUWEI  clu069     0  0.068352       NaN        1.0
# 97   fixate1  420   1.0  YUWEI  clu294     3  0.056551       NaN       10.0
# 102  fixate1  420   1.0  YUWEI  clu294     9  0.054885       NaN        1.0
#
#      best_lag
# 42          4
# 124         3
# 29          3
# 73          5
# 58          5
# ..        ...
# 103         8
# 96         11
# 13          5
# 97         10
# 102         2
#
# [141 rows x 10 columns]
