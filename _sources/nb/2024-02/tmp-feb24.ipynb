# %% [markdown]
# # tmp — feb24
#
# **Motivation**: scratch notebook <br>

# %%
# HIDE CODE


import os, sys
from IPython.display import display

# tmp & extras dir
git_dir = os.path.join(os.environ['HOME'], 'Dropbox/git')
extras_dir = os.path.join(git_dir, 'jb-MTMST/_extras')
fig_base_dir = os.path.join(git_dir, 'jb-MTMST/figs')
tmp_dir = os.path.join(git_dir, 'jb-MTMST/tmp')

# GitHub
sys.path.insert(0, os.path.join(git_dir, '_MTMST'))
from vae.train_vae import TrainerVAE, ConfigTrainVAE
from vae.vae2d import VAE, ConfigVAE
from figures.fighelper import *
from analysis.glm import *

# warnings, tqdm, & style
warnings.filterwarnings('ignore', category=DeprecationWarning)
from rich.jupyter import print
# %matplotlib inline
set_style()

# %% [markdown]
# ## Load model

# %%
# kaba:
mod_name = 'fixate1_z-14x[5,10,20]_k-32_d-17_enc(2x2)-dec(2x1)-pre(1x3)-post(1x3)_wn'
fit_name = 'ep500-b1200-lr(0.002)_beta(0.1:0x0.3)_lamb(0.01)_gr(250.0)_(2024_02_25,20:15)'

tr, metadata = load_model(
    model_name=mod_name,
    fit_name=fit_name,
    verbose=True,
    device='cuda',
)
# Out:
# +--------------+------------+
# | Module Name  | Num Params |
# +--------------+------------+
# |     VAE      |  39.3 Mil  |
# |     ---      |    ---     |
# |     stem     |    288     |
# | pre_process  |   95.7 K   |
# |  enc_tower   |  22.5 Mil  |
# |     enc0     |   65.8 K   |
# | enc_sampler  |  3.0 Mil   |
# | dec_sampler  |  3.0 Mil   |
# |    expand    |  286.6 K   |
# |  dec_tower   |  10.3 Mil  |
# | post_process |   39.9 K   |
# |     out      |    578     |
# +--------------+------------+
# # params: 39.3 M

# %%
vae = tr.model

# %%
print(vae.dec_tower)
# Out:
# ModuleList(
#   (0): CombinerDec(
#     (conv): Conv2d(270, 256, kernel_size=(1, 1), stride=(1, 1))
#   )
#   (1-2): 2 x Cell(
#     (skip): Identity()
#     (ops): ModuleList(
#       (0): ConvLayer(
#         (act_fn): SiLU()
#         (conv): Conv2D(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#     (se): SELayer(
#       (fc): Sequential(
#         (0): Linear(in_features=256, out_features=16, bias=True)
#         (1): ReLU(inplace=True)
#         (2): Linear(in_features=16, out_features=256, bias=True)
#         (3): Sigmoid()
#       )
#     )
#   )
#   (3): CombinerDec(
#     (conv): Conv2d(270, 256, kernel_size=(1, 1), stride=(1, 1))
#   )
#   (4-5): 2 x Cell(
#     (skip): Identity()
#     (ops): ModuleList(
#       (0): ConvLayer(
#         (act_fn): SiLU()
#         (conv): Conv2D(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#     (se): SELayer(
#       (fc): Sequential(
# ...

# %%
tr.cfg.optimizer_kws
# Out:
# {'betas': [0.9, 0.999], 'weight_decay': 0.0003, 'eps': 1e-08}

# %%
tr.cfg.scheduler_kws
# Out:
# {'T_max': 493.75, 'eta_min': 1e-05}

# %%
vars(tr.cfg)
# Out:
# {'lr': 0.002,
#  'epochs': 500,
#  'batch_size': 1200,
#  'warm_restart': 0,
#  'warmup_portion': 0.0125,
#  'optimizer': 'adamax_fast',
#  'optimizer_kws': {'betas': [0.9, 0.999],
#   'weight_decay': 0.0003,
#   'eps': 1e-08},
#  'scheduler_type': 'cosine',
#  'scheduler_kws': {'T_max': 493.75, 'eta_min': 1e-05},
#  'ema_rate': 0.999,
#  'grad_clip': 250.0,
#  'chkpt_freq': 20,
#  'eval_freq': 2,
#  'log_freq': 10,
#  'use_amp': False,
#  'kl_beta': 0.1,
#  'kl_beta_min': 0.0001,
#  'kl_balancer': 'equal',
#  'kl_anneal_cycles': 0,
#  'kl_anneal_portion': 0.3,
#  'kl_const_portion': 0.01,
#  'lambda_anneal': False,
#  'lambda_init': 1e-07,
#  'lambda_norm': 0.01,
#  'spectral_reg': False}

# %%
vars(tr.model.cfg)
# Out:
# {'sim': 'fixate1',
#  'n_ch': 32,
#  'ker_sz': 2,
#  'input_sz': 17,
#  'n_enc_cells': 2,
#  'n_enc_nodes': 2,
#  'n_dec_cells': 2,
#  'n_dec_nodes': 1,
#  'n_pre_cells': 3,
#  'n_pre_blocks': 1,
#  'n_post_cells': 3,
#  'n_post_blocks': 1,
#  'n_latent_scales': 3,
#  'n_latent_per_group': 14,
#  'n_groups_per_scale': 20,
#  'spectral_norm': 0,
#  'weight_norm': True,
#  'separable': False,
#  'compress': True,
#  'use_bn': False,
#  'groups': [20, 10, 5],
#  'base_dir': '/home/hadi/Documents/MTVAE',
#  'results_dir': '/home/hadi/Documents/MTVAE/results',
#  'runs_dir': '/home/hadi/Documents/MTVAE/runs/fixate1_z-14x[5,10,20]_k-32_d-17_enc(2x2)-dec(2x1)-pre(1x3)-post(1x3)_wn',
#  'save_dir': '/home/hadi/Documents/MTVAE/models/fixate1_z-14x[5,10,20]_k-32_d-17_enc(2x2)-dec(2x1)-pre(1x3)-post(1x3)_wn',
#  'data_dir': '/home/hadi/Documents/MTVAE/data',
#  'h_file': '/home/hadi/Documents/MTVAE/data/ALL_tres25.h5',
#  'sim_path': '/home/hadi/Documents/MTVAE/data/fixate1_dim-17_n-750k',
# ...
