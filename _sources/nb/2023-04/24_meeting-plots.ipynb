# %% [markdown]
# # (24) Make some figs
#
# **Motivation**: <br>

# %%
# HIDE CODE


import os, sys
from IPython.display import display

# tmp & extras dir
git_dir = os.path.join(os.environ['HOME'], 'Dropbox/git')
extras_dir = os.path.join(git_dir, 'jb-MTMST/_extras')
fig_base_dir = os.path.join(git_dir, 'jb-MTMST/figs')
tmp_dir = os.path.join(git_dir, 'jb-MTMST/tmp')

# GitHub
sys.path.insert(0, os.path.join(git_dir, '_MTMST'))
from vae.train_vae import TrainerVAE, ConfigTrainVAE
from vae.vae2d import VAE, ConfigVAE
from figures.fighelper import *
from analysis.glm import *


# warnings, tqdm, & style
warnings.filterwarnings('ignore', category=DeprecationWarning)
from rich.jupyter import print
# %matplotlib inline
set_style()

# %%
from base.dataset import ROFLDS

def _get_sim_path(sim):
    return f"/home/hadi/Documents/MTMST/data/{sim}_dim-17_n-750k"


datasets = {
    k: ROFLDS(_get_sim_path(k), 'tst') for k
    in ['fixate1', 'fixate0', 'obj1', 'fixate4']
}

# %%
inds = {
    'fixate1': [33, 37, 44, 46],
    'fixate0': [0, 8, 10, 15],
    'obj1': [2, 4, 5, 13],
}
x = []
for k, ii in inds.items():
    x.append(datasets[k].x[ii])
x = np.concatenate(x)
x.shape
# Out:
# (12, 2, 17, 17)

# %%
show_opticflow(x);

# %%
show_opticflow(datasets['fixate4'].x);

# %%
idx = i * 16 + 8

list(zip(ds.f, ds.g[idx]))
# Out:
# [('fix_x', 0.3434974760255516),
#  ('fix_y', 0.24501713389439583),
#  ('slf_v_norm', 0.9729499721731546),
#  ('slf_v_theta', 2.649948381979101),
#  ('slf_v_phi', 3.16244648339411),
#  ('obj0_alpha_x', -0.4908738521234052),
#  ('obj0_alpha_y', -0.09817477042468103),
#  ('obj0_distance', 0.8797457523993012),
#  ('obj0_v_norm', 0.03313022848030184),
#  ('obj0_v_theta', 1.3527333856535746),
#  ('obj0_v_phi', 3.6352871074253383)]

# %%
show_opticflow_full(ds.x[idx]);
