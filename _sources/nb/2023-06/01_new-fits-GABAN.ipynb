# %% [markdown]
# # (01) Neural results ($ skip + 0.1 * x \dots$ ```GABAN```)
#
# **Motivation**: Fits on ```GABAN``` <br>

# %%
# HIDE CODE


import os, sys
from IPython.display import display

# tmp & extras dir
git_dir = os.path.join(os.environ['HOME'], 'Dropbox/git')
extras_dir = os.path.join(git_dir, 'jb-MTMST/_extras')
fig_base_dir = os.path.join(git_dir, 'jb-MTMST/figs')
tmp_dir = os.path.join(git_dir, 'jb-MTMST/tmp')

# GitHub
sys.path.insert(0, os.path.join(git_dir, '_MTMST'))
from vae.train_vae import TrainerVAE, ConfigTrainVAE
from vae.vae2d import VAE, ConfigVAE
from figures.fighelper import *
from analysis.glm import *


# warnings, tqdm, & style
warnings.filterwarnings('ignore', category=DeprecationWarning)
from rich.jupyter import print
# %matplotlib inline
set_style()

# %%
fits = [
    'fixate1_z-14x[5,10,20]_k-32_d-17_enc(2x2)-dec(2x1)-pre(1x3)-post(1x3)/wnfix_ep500-b1200-lr(0.002)_beta(0.1:0x0.3)_lamb(0.01)_gr(250.0)_(2023_06_18,13:43)',
]
save_script_neural(fits, 'cuda')
# Out:
# [PROGRESS] 'run_neuron_gaban.txt' saved at
# /home/hadi/Dropbox/git/_MTMST/scripts

# %% [markdown]
# ## Bug in ```HyperFlow``` fixed

# %%
fit_name = 'fixate1_nf-490_beta-0.1_(2023_07_04,18:41)'
df, df_all, ro_all, args, tr = summarize_neural_fits(fit_name)

_ = show_neural_results(df)
len(df)
# Out:
# 24

# %%
inds = df['perf'].argsort()[::-1]
df.iloc[inds]
# Out:
#    category   nf  beta   root    expt  cell      perf  max_perf  log_alpha  \
# 17  fixate1  490   0.1  YUWEI  clu088     0  0.785975  0.646108       12.0
# 19  fixate1  490   0.1  YUWEI  clu090     0  0.766111  0.990020        6.0
# 23  fixate1  490   0.1  YUWEI  clu104     0  0.666573  0.980831        5.0
# 21  fixate1  490   0.1  YUWEI  clu096     0  0.650214  0.909688        8.0
# 18  fixate1  490   0.1  YUWEI  clu089     0  0.637834  0.953892        3.0
# 20  fixate1  490   0.1  YUWEI  clu095     0  0.614843  0.956606        6.0
# 22  fixate1  490   0.1  YUWEI  clu099     0  0.602760  0.940023       12.0
# 9   fixate1  490   0.1  YUWEI  clu059     0  0.558859       NaN        0.0
# 4   fixate1  490   0.1  YUWEI  clu040     0  0.520858       NaN        0.0
# 16  fixate1  490   0.1  YUWEI  clu087     0  0.484099       NaN        2.0
# 7   fixate1  490   0.1  YUWEI  clu053     0  0.450231       NaN        2.0
# 14  fixate1  490   0.1  YUWEI  clu081     0  0.429568       NaN        0.0
# 5   fixate1  490   0.1  YUWEI  clu043     0  0.392450       NaN        2.0
# 3   fixate1  490   0.1  YUWEI  clu039     0  0.391988       NaN        2.0
# 8   fixate1  490   0.1  YUWEI  clu055     0  0.377192       NaN        1.0
# 2   fixate1  490   0.1  YUWEI  clu038     0  0.362333       NaN        2.0
# 11  fixate1  490   0.1  YUWEI  clu064     0  0.349693       NaN        2.0
# 6   fixate1  490   0.1  YUWEI  clu044     0  0.331723       NaN        0.0
# 12  fixate1  490   0.1  YUWEI  clu068     0  0.300549       NaN        2.0
# 15  fixate1  490   0.1  YUWEI  clu082     0  0.270495       NaN        5.0
# 1   fixate1  490   0.1  YUWEI  clu037     0  0.255654       NaN        2.0
# 10  fixate1  490   0.1  YUWEI  clu061     0  0.149051       NaN        3.0
# 0   fixate1  490   0.1  YUWEI  clu036     0  0.133096       NaN        4.0
# 13  fixate1  490   0.1  YUWEI  clu069     0  0.079103       NaN        5.0
#
#     best_lag
# 17         3
# 19         2
# 23         3
# 21         1
# 18         0
# 20         2
# 22         4
# 9          3
# 4          4
# 16         4
# 7          5
# 14         3
# 5          4
# 3          0
# 8          4
# 2          1
# 11         3
# 6          3
# 12         4
# 15         3
# 1          8
# 10         4
# 0          2
# 13         4

# %%
# Out:
# 141

# %%
# Out:
#     category   nf  beta   root    expt  cell      perf  max_perf  log_alpha  \
# 69   fixate1  490   0.1  YUWEI  clu267     4  0.859217  0.979806        4.0
# 28   fixate1  490   0.1  YUWEI  clu116     0  0.849260  0.835483       -6.0
# 42   fixate1  490   0.1  YUWEI  clu209     1  0.834028  0.923722        3.0
# 72   fixate1  490   0.1  YUWEI  clu267     7  0.813340  0.955361      -10.0
# 54   fixate1  490   0.1  YUWEI  clu222     0  0.796979  0.969344        3.0
# ..       ...  ...   ...    ...     ...   ...       ...       ...        ...
# 0    fixate1  490   0.1  YUWEI  clu036     0  0.132054       NaN        4.0
# 96   fixate1  490   0.1  YUWEI  clu294     2  0.123331       NaN        6.0
# 97   fixate1  490   0.1  YUWEI  clu294     3  0.086547       NaN        6.0
# 13   fixate1  490   0.1  YUWEI  clu069     0  0.078099       NaN        5.0
# 102  fixate1  490   0.1  YUWEI  clu294     9  0.068577       NaN        6.0
#
#      best_lag
# 69          5
# 28          4
# 42          4
# 72          5
# 54          1
# ..        ...
# 0           3
# 96          8
# 97          4
# 13          5
# 102         3
#
# [141 rows x 10 columns]

# %% [markdown]
# ## Weight reg fixed
# Did not apply to ```Sampler``` layers.

# %%
fits = {
    'before HF fix': 'fixate1_nf-490_beta-0.1_(2023_06_23,16:58)',
    'after HF fix': 'fixate1_nf-490_beta-0.1_(2023_07_04,18:41)',
}
for k, fit_name in fits.items():
    df, df_all, ro_all, args, tr = summarize_neural_fits(fit_name)
    fig, _ = show_neural_results(df, display=False)
    fig.suptitle(f"comment: {k},  perf: {df['perf'].mean():0.3f}\nname: {fit_name}", y=1.12, fontsize=11)
    display(fig)

# %%
df[:20]
# Out:
#    category   nf  beta   root    expt  cell      perf  max_perf  log_alpha  \
# 0   fixate1  490   0.1  YUWEI  clu036     0  0.133096       NaN        4.0
# 1   fixate1  490   0.1  YUWEI  clu037     0  0.255654       NaN        2.0
# 2   fixate1  490   0.1  YUWEI  clu038     0  0.362333       NaN        2.0
# 3   fixate1  490   0.1  YUWEI  clu039     0  0.391988       NaN        2.0
# 4   fixate1  490   0.1  YUWEI  clu040     0  0.520858       NaN        0.0
# 5   fixate1  490   0.1  YUWEI  clu043     0  0.392450       NaN        2.0
# 6   fixate1  490   0.1  YUWEI  clu044     0  0.331723       NaN        0.0
# 7   fixate1  490   0.1  YUWEI  clu053     0  0.450231       NaN        2.0
# 8   fixate1  490   0.1  YUWEI  clu055     0  0.377192       NaN        1.0
# 9   fixate1  490   0.1  YUWEI  clu059     0  0.558859       NaN        0.0
# 10  fixate1  490   0.1  YUWEI  clu061     0  0.149051       NaN        3.0
# 11  fixate1  490   0.1  YUWEI  clu064     0  0.349693       NaN        2.0
# 12  fixate1  490   0.1  YUWEI  clu068     0  0.300549       NaN        2.0
# 13  fixate1  490   0.1  YUWEI  clu069     0  0.079103       NaN        5.0
# 14  fixate1  490   0.1  YUWEI  clu081     0  0.429568       NaN        0.0
# 15  fixate1  490   0.1  YUWEI  clu082     0  0.270495       NaN        5.0
# 16  fixate1  490   0.1  YUWEI  clu087     0  0.484099       NaN        2.0
# 17  fixate1  490   0.1  YUWEI  clu088     0  0.785975  0.646108       12.0
# 18  fixate1  490   0.1  YUWEI  clu089     0  0.637834  0.953892        3.0
# 19  fixate1  490   0.1  YUWEI  clu090     0  0.766111  0.990020        6.0
#
#     best_lag
# 0          2
# 1          8
# 2          1
# 3          0
# 4          4
# 5          4
# 6          3
# 7          5
# 8          4
# 9          3
# 10         4
# 11         3
# 12         4
# 13         4
# 14         3
# 15         3
# 16         4
# 17         3
# 18         0
# 19         2

# %%
df[:20]
# Out:
#    category   nf  beta   root    expt  cell      perf  max_perf  log_alpha  \
# 0   fixate1  490   0.1  YUWEI  clu036     0  0.132054       NaN        4.0
# 1   fixate1  490   0.1  YUWEI  clu037     0  0.284023       NaN        2.0
# 2   fixate1  490   0.1  YUWEI  clu038     0  0.367205       NaN        2.0
# 3   fixate1  490   0.1  YUWEI  clu039     0  0.400086       NaN        3.0
# 4   fixate1  490   0.1  YUWEI  clu040     0  0.522885       NaN      -10.0
# 5   fixate1  490   0.1  YUWEI  clu043     0  0.399614       NaN        2.0
# 6   fixate1  490   0.1  YUWEI  clu044     0  0.343661       NaN        0.0
# 7   fixate1  490   0.1  YUWEI  clu053     0  0.440737       NaN      -10.0
# 8   fixate1  490   0.1  YUWEI  clu055     0  0.399960       NaN        0.0
# 9   fixate1  490   0.1  YUWEI  clu059     0  0.582895       NaN      -10.0
# 10  fixate1  490   0.1  YUWEI  clu061     0  0.163395       NaN        3.0
# 11  fixate1  490   0.1  YUWEI  clu064     0  0.358434       NaN        0.0
# 12  fixate1  490   0.1  YUWEI  clu068     0  0.312026       NaN      -10.0
# 13  fixate1  490   0.1  YUWEI  clu069     0  0.078099       NaN        5.0
# 14  fixate1  490   0.1  YUWEI  clu081     0  0.443734       NaN      -10.0
# 15  fixate1  490   0.1  YUWEI  clu082     0  0.268443       NaN        5.0
# 16  fixate1  490   0.1  YUWEI  clu087     0  0.489355       NaN      -10.0
# 17  fixate1  490   0.1  YUWEI  clu088     0  0.742595  0.646108       -1.0
# 18  fixate1  490   0.1  YUWEI  clu089     0  0.709327  0.953892       -4.0
# 19  fixate1  490   0.1  YUWEI  clu090     0  0.766532  0.990020       -6.0
#
#     best_lag
# 0          3
# 1          6
# 2          0
# 3          0
# 4          2
# 5          5
# 6          3
# 7          5
# 8          4
# 9          3
# 10         4
# 11         3
# 12         4
# 13         5
# 14         3
# 15         3
# 16         4
# 17         2
# 18         1
# 19         1

# %% [markdown]
# ## Show results

# %%
fits = [
    'fixate1_nf-300_beta-0.15_(2023_06_05,17:23)',
    'fixate1_nf-490_beta-0.15_(2023_06_05,00:13)',
    'fixate1_nf-560_beta-0.15_(2023_06_05,02:52)',
    'fixate1_nf-504_beta-0.15_(2023_06_05,05:39)',
]
for fit_name in fits:
    df, df_all, ro_all, args, tr = summarize_neural_fits(fit_name)
    fig, _ = show_neural_results(df, display=False)
    fig.suptitle(fit_name, y=1.07, fontsize=12)
    display(fig)
